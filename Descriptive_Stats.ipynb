# %%
import numpy as np
import pandas as pd

# %%
import os

directory = os.getcwd()
data = pd.read_csv(directory + '/EMS_2017_2018.csv', sep=',') 
data = pd.DataFrame(data)

# %%
data.head()
# Out:
#    Unnamed: 0  CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0           0        183654386  12/31/2018 11:59:46 PM            CARDBR
# 1           1        183654385  12/31/2018 11:59:20 PM            MVAINJ
# 2           2        183654384  12/31/2018 11:58:45 PM              SICK
# 3           3        183654383  12/31/2018 11:58:14 PM            INJMAJ
# 4           4        183654382  12/31/2018 11:57:42 PM               UNC
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            2          CARDBR                          2
# 1                            4          MVAINJ                          4
# 2                            6            SICK                          6
# 3                            3          INJMAJ                          3
# 4                            2             UNC                          2
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0    12/31/2018 11:59:54 PM                              Y
# 1    01/01/2019 12:01:10 AM                              Y
# 2    01/01/2019 12:00:43 AM                              Y
# 3    12/31/2018 11:58:22 PM                              Y
# 4    01/01/2019 12:00:39 AM                              Y
#
#    DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  \
# 0                             8    01/01/2019 12:00:51 AM
# 1                           110    01/01/2019 12:02:25 AM
# 2                           118    01/01/2019 12:02:08 AM
# 3                             8    12/31/2018 11:58:37 PM
# 4                           177    01/01/2019 12:01:03 AM
#
#   FIRST_ON_SCENE_DATETIME VALID_INCIDENT_RSPNS_TIME_INDC  \
# 0  01/01/2019 12:07:27 AM                              Y
# 1  01/01/2019 12:07:19 AM                              Y
# 2  01/01/2019 12:14:18 AM                              Y
# 3  01/01/2019 12:04:10 AM                              Y
# 4  01/01/2019 12:15:00 AM                              Y
#
#    INCIDENT_RESPONSE_SECONDS_QY  INCIDENT_TRAVEL_TM_SECONDS_QY  \
# 0                         461.0                          453.0
# 1                         479.0                          369.0
# 2                         933.0                          815.0
# 3                         356.0                          348.0
# 4                        1038.0                          861.0
#
#    FIRST_TO_HOSP_DATETIME FIRST_HOSP_ARRIVAL_DATETIME INCIDENT_CLOSE_DATETIME  \
# 0  01/01/2019 12:15:08 AM      01/01/2019 12:21:51 AM  01/01/2019 01:00:20 AM
# 1                     NaN                         NaN  01/01/2019 12:19:49 AM
# 2  01/01/2019 12:23:59 AM      01/01/2019 12:34:07 AM  01/01/2019 01:21:30 AM
# 3  01/01/2019 01:06:29 AM      01/01/2019 01:15:30 AM  01/01/2019 02:02:12 AM
# 4  01/01/2019 01:18:22 AM      01/01/2019 01:22:01 AM  01/01/2019 02:34:19 AM
#
#   HELD_INDICATOR  INCIDENT_DISPOSITION_CODE    BOROUGH INCIDENT_DISPATCH_AREA  \
# 0              N                       82.0   BROOKLYN                     K6
# 1              N                       91.0     QUEENS                     Q3
# 2              N                       82.0     QUEENS                     Q6
# 3              N                       82.0   BROOKLYN                     K1
# 4              N                       82.0  MANHATTAN                     M3
#
#    ZIPCODE  POLICEPRECINCT  CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  \
# 0  11201.0            84.0                 35.0              302.0
# 1  11416.0           102.0                 32.0              409.0
# 2  11369.0           115.0                 21.0              480.0
# 3  11214.0            62.0                 47.0              311.0
# 4  10019.0            18.0                  4.0              105.0
#
#    COMMUNITYSCHOOLDISTRICT  CONGRESSIONALDISTRICT REOPEN_INDICATOR  \
# 0                     13.0                    8.0                N
# 1                     27.0                    7.0                N
# 2                     30.0                   14.0                N
# 3                     20.0                   11.0                N
# 4                      2.0                   12.0                N
#
#   SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR TRANSFER_INDICATOR Incident_Time  \
# 0                       N                 N                  N    12/31/2018
# 1                       N                 N                  N    12/31/2018
# 2                       N                 N                  N    12/31/2018
# 3                       N                 N                  N    12/31/2018
# 4                       N                 N                  N    12/31/2018
#
#   Incident_Date
# 0   11:59:46 PM
# 1   11:59:20 PM
# 2   11:58:45 PM
# 3   11:58:14 PM
# 4   11:57:42 PM

# %%
data.shape
# Out:
# (3001488, 36)

# %% [markdown]
# ***Converting Times to DATETIME***

# %%
import time
from time import mktime
from datetime import datetime as dt

# %%
data["FIRST_ASSIGNMENT_DATETIME"] = pd.to_datetime(data["FIRST_ASSIGNMENT_DATETIME"])

# %%
data["INCIDENT_DATETIME"] = pd.to_datetime(data["INCIDENT_DATETIME"])

# %%
data.head()
# Out:
#    Unnamed: 0  CAD_INCIDENT_ID   INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0           0        183654386 2018-12-31 23:59:46            CARDBR
# 1           1        183654385 2018-12-31 23:59:20            MVAINJ
# 2           2        183654384 2018-12-31 23:58:45              SICK
# 3           3        183654383 2018-12-31 23:58:14            INJMAJ
# 4           4        183654382 2018-12-31 23:57:42               UNC
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            2          CARDBR                          2
# 1                            4          MVAINJ                          4
# 2                            6            SICK                          6
# 3                            3          INJMAJ                          3
# 4                            2             UNC                          2
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0       2018-12-31 23:59:54                              Y
# 1       2019-01-01 00:01:10                              Y
# 2       2019-01-01 00:00:43                              Y
# 3       2018-12-31 23:58:22                              Y
# 4       2019-01-01 00:00:39                              Y
#
#    DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  \
# 0                             8    01/01/2019 12:00:51 AM
# 1                           110    01/01/2019 12:02:25 AM
# 2                           118    01/01/2019 12:02:08 AM
# 3                             8    12/31/2018 11:58:37 PM
# 4                           177    01/01/2019 12:01:03 AM
#
#   FIRST_ON_SCENE_DATETIME VALID_INCIDENT_RSPNS_TIME_INDC  \
# 0  01/01/2019 12:07:27 AM                              Y
# 1  01/01/2019 12:07:19 AM                              Y
# 2  01/01/2019 12:14:18 AM                              Y
# 3  01/01/2019 12:04:10 AM                              Y
# 4  01/01/2019 12:15:00 AM                              Y
#
#    INCIDENT_RESPONSE_SECONDS_QY  INCIDENT_TRAVEL_TM_SECONDS_QY  \
# 0                         461.0                          453.0
# 1                         479.0                          369.0
# 2                         933.0                          815.0
# 3                         356.0                          348.0
# 4                        1038.0                          861.0
#
#    FIRST_TO_HOSP_DATETIME FIRST_HOSP_ARRIVAL_DATETIME INCIDENT_CLOSE_DATETIME  \
# 0  01/01/2019 12:15:08 AM      01/01/2019 12:21:51 AM  01/01/2019 01:00:20 AM
# 1                     NaN                         NaN  01/01/2019 12:19:49 AM
# 2  01/01/2019 12:23:59 AM      01/01/2019 12:34:07 AM  01/01/2019 01:21:30 AM
# 3  01/01/2019 01:06:29 AM      01/01/2019 01:15:30 AM  01/01/2019 02:02:12 AM
# 4  01/01/2019 01:18:22 AM      01/01/2019 01:22:01 AM  01/01/2019 02:34:19 AM
#
#   HELD_INDICATOR  INCIDENT_DISPOSITION_CODE    BOROUGH INCIDENT_DISPATCH_AREA  \
# 0              N                       82.0   BROOKLYN                     K6
# 1              N                       91.0     QUEENS                     Q3
# 2              N                       82.0     QUEENS                     Q6
# 3              N                       82.0   BROOKLYN                     K1
# 4              N                       82.0  MANHATTAN                     M3
#
#    ZIPCODE  POLICEPRECINCT  CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  \
# 0  11201.0            84.0                 35.0              302.0
# 1  11416.0           102.0                 32.0              409.0
# 2  11369.0           115.0                 21.0              480.0
# 3  11214.0            62.0                 47.0              311.0
# 4  10019.0            18.0                  4.0              105.0
#
#    COMMUNITYSCHOOLDISTRICT  CONGRESSIONALDISTRICT REOPEN_INDICATOR  \
# 0                     13.0                    8.0                N
# 1                     27.0                    7.0                N
# 2                     30.0                   14.0                N
# 3                     20.0                   11.0                N
# 4                      2.0                   12.0                N
#
#   SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR TRANSFER_INDICATOR Incident_Time  \
# 0                       N                 N                  N    12/31/2018
# 1                       N                 N                  N    12/31/2018
# 2                       N                 N                  N    12/31/2018
# 3                       N                 N                  N    12/31/2018
# 4                       N                 N                  N    12/31/2018
#
#   Incident_Date
# 0   11:59:46 PM
# 1   11:59:20 PM
# 2   11:58:45 PM
# 3   11:58:14 PM
# 4   11:57:42 PM

# %% [markdown]
# ***Summary Statistics***

# %%
def getDfSummary(input_data):
    stats = pd.DataFrame(input_data.describe(include=[np.number]).transpose()) #stats but only include #s
    number_nan = pd.DataFrame(input_data.isna().sum(),columns = ['number_nan']) #NaN value count
    number_distinct = pd.DataFrame(input_data.nunique(),columns = ['number_distinct']) #unique values
    output_data = pd.concat([stats, number_nan, number_distinct], axis=1) #axis=1: stack to right of first col
    output_data = output_data.drop("count", axis = 1)
    return output_data

# %% [markdown]
# Summary statistics are only useful for numeric data, so in our case, it is only useful for the duration data: `DISPATCH_RESPONSE_SECONDS_QY`, `INCIDENT_RESPONSE_SECONDS_QY`, `INCIDENT_TRAVEL_TM_SECONDS_QY`. The minimum value of all 3 of these durations is 0, therefore indicating that EMS was already on site or on standby.
#
# Time-stamped data does not produce useful summary statistics except in the case of seeing how many missing values and unique values we have. This is for the following: `FIRST_ACTIVATION_DATETIME`,`FIRST_ASSIGNMENT_DATETIME`, `FIRST_HOSP_ARRIVAL_DATETIME`, `FIRST_ON_SCENE_DATETIME`, `FIRST_TO_HOSP_DATETIME`, `INCIDENT_CLOSE_DATETIME`, `INCIDENT_DATETIME`.
#
# Categorical data does not produce useful summary statistics either, excpet in the case of showing missing values and unique values. This is for the following: `BOROUGH`, `CITYCOUNCILDISTRICT`, `COMMUNITYDISTRICT`, `COMMUNITYSCHOOLDISTRICT`, `CONGRESSIONALDISTRICT `, `FINAL_CALL_TYPE `, `FINAL_SEVERITY_LEVEL_CODE`, `INCIDENT_DISPATCH_AREA`, `INCIDENT_DISPOSITION_CODE`, `INITAL_CALL_TYPE`, `INITIAL_SEVERITY_LEVEL_CODE `, `POLICEPRECINCT`, `ZIPCODE `.
#
# Binary data does not produce useful summary statistics, except to show how many missing values exist. This is for the following: `HELD_INDICATOR`, `REOPEN_INDICATOR`, `SPECIAL_EVENT_INDICATOR`, `STANDBY_INDICATOR`, `TRANSFER_INDICATOR`, `VALID_DISPATCH_RSPNS_TIME_INDC`, `VALID_INDICDENT_RSPNS_TIME_INDC`.
#
# We should only use incidents where these indicators are true: `VALID_DISPATCH_RSPNS_TIME_INDC`, and `VALID_INCIDENT_RSPNS_TIME_INDC`,

# %%
getDfSummary(data)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """
#                                         mean           std          min  \
# Assignment_Date                          NaN           NaN          NaN
# Assignment_Time                          NaN           NaN          NaN
# BOROUGH                                  NaN           NaN          NaN
# CAD_INCIDENT_ID                 1.769487e+08  5.101642e+06  170010001.0
# CITYCOUNCILDISTRICT             2.286989e+01  1.498182e+01          1.0
# COMMUNITYDISTRICT               2.602660e+02  1.181678e+02        101.0
# COMMUNITYSCHOOLDISTRICT         1.464839e+01  9.614933e+00          1.0
# CONGRESSIONALDISTRICT           1.064885e+01  3.332767e+00          3.0
# DISPATCH_RESPONSE_SECONDS_QY    7.093197e+01  5.070557e+02          0.0
# FINAL_CALL_TYPE                          NaN           NaN          NaN
# FINAL_SEVERITY_LEVEL_CODE       4.177328e+00  1.725233e+00          1.0
# FIRST_ACTIVATION_DATETIME                NaN           NaN          NaN
# FIRST_ASSIGNMENT_DATETIME                NaN           NaN          NaN
# FIRST_HOSP_ARRIVAL_DATETIME              NaN           NaN          NaN
# FIRST_ON_SCENE_DATETIME                  NaN           NaN          NaN
# FIRST_TO_HOSP_DATETIME                   NaN           NaN          NaN
# HELD_INDICATOR                           NaN           NaN          NaN
# INCIDENT_CLOSE_DATETIME                  NaN           NaN          NaN
# INCIDENT_DATETIME                        NaN           NaN          NaN
# INCIDENT_DISPATCH_AREA                   NaN           NaN          NaN
# INCIDENT_DISPOSITION_CODE       8.488739e+01  4.662948e+00         82.0
# INCIDENT_RESPONSE_SECONDS_QY    5.592685e+02  6.594879e+02          0.0
# INCIDENT_TRAVEL_TM_SECONDS_QY   4.901194e+02  3.917800e+02          0.0
# INITIAL_CALL_TYPE                        NaN           NaN          NaN
# INITIAL_SEVERITY_LEVEL_CODE     4.272623e+00  1.724687e+00          1.0
# Incident_Date                            NaN           NaN          NaN
# Incident_Time                            NaN           NaN          NaN
# POLICEPRECINCT                  6.136637e+01  3.419861e+01          1.0
# REOPEN_INDICATOR                         NaN           NaN          NaN
# SPECIAL_EVENT_INDICATOR                  NaN           NaN          NaN
# STANDBY_INDICATOR                        NaN           NaN          NaN
# TRANSFER_INDICATOR                       NaN           NaN          NaN
# Unnamed: 0                      1.500744e+06  8.664551e+05          0.0
# VALID_DISPATCH_RSPNS_TIME_INDC           NaN           NaN          NaN
# VALID_INCIDENT_RSPNS_TIME_INDC           NaN           NaN          NaN
# ZIPCODE                         1.073116e+04  5.501269e+02         83.0
#
#                                          25%          50%           75%  \
# Assignment_Date                          NaN          NaN           NaN
# Assignment_Time                          NaN          NaN           NaN
# BOROUGH                                  NaN          NaN           NaN
# CAD_INCIDENT_ID                 1.718826e+08  180083308.5  1.818711e+08
# CITYCOUNCILDISTRICT             9.000000e+00         20.0  3.600000e+01
# COMMUNITYDISTRICT               1.120000e+02        301.0  3.170000e+02
# COMMUNITYSCHOOLDISTRICT         6.000000e+00         13.0  2.300000e+01
# CONGRESSIONALDISTRICT           8.000000e+00         11.0  1.300000e+01
# DISPATCH_RESPONSE_SECONDS_QY    1.100000e+01         18.0  3.500000e+01
# FINAL_CALL_TYPE                          NaN          NaN           NaN
# FINAL_SEVERITY_LEVEL_CODE       3.000000e+00          4.0  6.000000e+00
# FIRST_ACTIVATION_DATETIME                NaN          NaN           NaN
# FIRST_ASSIGNMENT_DATETIME                NaN          NaN           NaN
# FIRST_HOSP_ARRIVAL_DATETIME              NaN          NaN           NaN
# FIRST_ON_SCENE_DATETIME                  NaN          NaN           NaN
# FIRST_TO_HOSP_DATETIME                   NaN          NaN           NaN
# HELD_INDICATOR                           NaN          NaN           NaN
# INCIDENT_CLOSE_DATETIME                  NaN          NaN           NaN
# INCIDENT_DATETIME                        NaN          NaN           NaN
# INCIDENT_DISPATCH_AREA                   NaN          NaN           NaN
# INCIDENT_DISPOSITION_CODE       8.200000e+01         82.0  9.000000e+01
# INCIDENT_RESPONSE_SECONDS_QY    3.080000e+02        436.0  6.280000e+02
# INCIDENT_TRAVEL_TM_SECONDS_QY   2.830000e+02        406.0  5.830000e+02
# INITIAL_CALL_TYPE                        NaN          NaN           NaN
# INITIAL_SEVERITY_LEVEL_CODE     3.000000e+00          4.0  6.000000e+00
# Incident_Date                            NaN          NaN           NaN
# Incident_Time                            NaN          NaN           NaN
# POLICEPRECINCT                  3.400000e+01         60.0  8.800000e+01
# REOPEN_INDICATOR                         NaN          NaN           NaN
# SPECIAL_EVENT_INDICATOR                  NaN          NaN           NaN
# STANDBY_INDICATOR                        NaN          NaN           NaN
# TRANSFER_INDICATOR                       NaN          NaN           NaN
# Unnamed: 0                      7.503718e+05    1500743.5  2.251115e+06
# VALID_DISPATCH_RSPNS_TIME_INDC           NaN          NaN           NaN
# VALID_INCIDENT_RSPNS_TIME_INDC           NaN          NaN           NaN
# ZIPCODE                         1.012800e+04      10470.0  1.122600e+04
#
#                                         max  number_nan  number_distinct
# Assignment_Date                         NaN       15956              731
# Assignment_Time                         NaN       15956            86399
# BOROUGH                                 NaN           0                6
# CAD_INCIDENT_ID                 183654386.0           0          3001488
# CITYCOUNCILDISTRICT                    51.0       38938               51
# COMMUNITYDISTRICT                     595.0       38831               71
# COMMUNITYSCHOOLDISTRICT                32.0       41389               32
# CONGRESSIONALDISTRICT                  16.0       38938               13
# DISPATCH_RESPONSE_SECONDS_QY        32332.0           0             7077
# FINAL_CALL_TYPE                         NaN           0              126
# FINAL_SEVERITY_LEVEL_CODE               8.0           0                8
# FIRST_ACTIVATION_DATETIME               NaN       20328          2907100
# FIRST_ASSIGNMENT_DATETIME               NaN       15956          2915418
# FIRST_HOSP_ARRIVAL_DATETIME             NaN      927868          2009643
# FIRST_ON_SCENE_DATETIME                 NaN       90183          2840077
# FIRST_TO_HOSP_DATETIME                  NaN      914112          2079120
# HELD_INDICATOR                          NaN           0                2
# INCIDENT_CLOSE_DATETIME                 NaN         813          2922126
# INCIDENT_DATETIME                       NaN           0          2947469
# INCIDENT_DISPATCH_AREA                  NaN           0               39
# INCIDENT_DISPOSITION_CODE              96.0       19887               10
# INCIDENT_RESPONSE_SECONDS_QY        32377.0       90735             8756
# INCIDENT_TRAVEL_TM_SECONDS_QY       87386.0       90226             5658
# INITIAL_CALL_TYPE                       NaN           0              110
# INITIAL_SEVERITY_LEVEL_CODE             9.0           0                9
# Incident_Date                           NaN           0            86400
# Incident_Time                           NaN           0              730
# POLICEPRECINCT                        123.0       38829               77
# REOPEN_INDICATOR                        NaN           0                2
# SPECIAL_EVENT_INDICATOR                 NaN           0                2
# STANDBY_INDICATOR                       NaN           0                2
# TRANSFER_INDICATOR                      NaN           0                2
# Unnamed: 0                        3001487.0           0          3001488
# VALID_DISPATCH_RSPNS_TIME_INDC          NaN           0                2
# VALID_INCIDENT_RSPNS_TIME_INDC          NaN           0                2
# ZIPCODE                             12345.0       38930              237

# %% [markdown]
# ***ASSIGNMENT DATETIME***

# %% [markdown]
# ***Number of Incidents per Time Assigned***

# %% [markdown]
# Binning Assignment dates/times to determine which bins to use for modeling.  Likely best to just use every hour interval so as to not bias the data and group too many incidents together. Bins are created by default in Python using optimal # of bins. Too many bins are created this way so we can see what it looks like when we have 24 bins (1 to represent each hour). Rather than subjectively choose time intervals to represent morning, afternoon, evening, rush hour, etc, may be best to just use 1 hour intervals otherwise we may introduce bias into the model.

# %%
#Converting time to a number between 0 and 24
t_s = data["FIRST_ASSIGNMENT_DATETIME"].dt.hour+data["FIRST_ASSIGNMENT_DATETIME"].dt.minute/60+(data["FIRST_ASSIGNMENT_DATETIME"].dt.second/60/100)

# %%
#some nan values because there are missing assignment times
#if there is no assignment time, we are not interested because that means the incident was never assigned and therefore no response time
#drop the nan values so we can see count of assignment times from 0 - 24 and create appropriate bins
t_s = t_s.dropna()
count_nan = len(t_s) - t_s.count()
count_nan

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(t_s, hist=True, kde=False, rug=False, label='Bins: Default')
sns.distplot(t_s, hist=True, kde=False, rug=False, bins=24, label='Bins: 24')
plt.xticks(np.arange(1,25))
plt.xlim(0,24)
plt.xlabel("Time Assigned (hr)")
plt.ylabel("Number of Incidents")
plt.legend()
plt.show()

# %% [markdown]
# ***Coding Time Bins per Hour***

# %%
bins = dict(zip(pd.date_range('2010-01-01', '2010-01-01 23:59:59', freq='60T').hour, range(24)))

# %%
data['Time_Code'] = data["FIRST_ASSIGNMENT_DATETIME"].dt.hour.map(bins)

# %%
data.head()
# Out:
#    Unnamed: 0  CAD_INCIDENT_ID   INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0           0        183654386 2018-12-31 23:59:46            CARDBR
# 1           1        183654385 2018-12-31 23:59:20            MVAINJ
# 2           2        183654384 2018-12-31 23:58:45              SICK
# 3           3        183654383 2018-12-31 23:58:14            INJMAJ
# 4           4        183654382 2018-12-31 23:57:42               UNC
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            2          CARDBR                          2
# 1                            4          MVAINJ                          4
# 2                            6            SICK                          6
# 3                            3          INJMAJ                          3
# 4                            2             UNC                          2
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0       2018-12-31 23:59:54                              Y
# 1       2019-01-01 00:01:10                              Y
# 2       2019-01-01 00:00:43                              Y
# 3       2018-12-31 23:58:22                              Y
# 4       2019-01-01 00:00:39                              Y
#
#    DISPATCH_RESPONSE_SECONDS_QY  ... CONGRESSIONALDISTRICT REOPEN_INDICATOR  \
# 0                             8  ...                   8.0                N
# 1                           110  ...                   7.0                N
# 2                           118  ...                  14.0                N
# 3                             8  ...                  11.0                N
# 4                           177  ...                  12.0                N
#
#   SPECIAL_EVENT_INDICATOR  STANDBY_INDICATOR  TRANSFER_INDICATOR  \
# 0                       N                  N                   N
# 1                       N                  N                   N
# 2                       N                  N                   N
# 3                       N                  N                   N
# 4                       N                  N                   N
#
#   Incident_Time Incident_Date Assignment_Date Assignment_Time  Time_Code
# 0    12/31/2018   11:59:46 PM      2018-12-31        23:59:54       23.0
# 1    12/31/2018   11:59:20 PM      2019-01-01        00:01:10        0.0
# 2    12/31/2018   11:58:45 PM      2019-01-01        00:00:43        0.0
# 3    12/31/2018   11:58:14 PM      2018-12-31        23:58:22       23.0
# 4    12/31/2018   11:57:42 PM      2019-01-01        00:00:39        0.0
#
# [5 rows x 37 columns]

# %%
t_code = collections.Counter(data["Time_Code"])
tot_t_code = sum(t_code.values())

# %%
t_code
# Out:
# Counter({23.0: 118763,
#          0.0: 106334,
#          nan: 1,
#          nan: 1,
#          22.0: 134212,
#          nan: 1,
#          nan: 1,
#          21.0: 143504,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          20.0: 148395,
#          19.0: 152633,
#          nan: 1,
#          18.0: 155061,
#          nan: 1,
#          17.0: 156545,
#          16.0: 158481,
#          15.0: 158034,
#          nan: 1,
#          14.0: 157767,
#          nan: 1,
#          nan: 1,
#          13.0: 158046,
#          nan: 1,
#          12.0: 157158,
#          nan: 1,
#          11.0: 154189,
#          10.0: 148573,
#          nan: 1,
#          nan: 1,
#          9.0: 137802,
#          nan: 1,
#          8.0: 113035,
#          7.0: 86170,
#          6.0: 67785,
#          nan: 1,
#          5.0: 61675,
#          4.0: 66567,
#          3.0: 71813,
#          2.0: 80218,
#          1.0: 92772,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          ...})

# %%
t_code = {k: (v*100) / tot_t_code for k, v in t_code.items()} #mult by 100 to turn into percent
plt.bar(t_code.keys(),t_code.values())
plt.grid(axis = 'x')
plt.xlabel("Time Code")
plt.ylabel("Frequency (%)")
plt.show()

# %% [markdown]
# ***INCIDENT TRAVEL TIME vs TIME ASSIGNED***

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#Travel Response time over every incident time
plt.figure(figsize =(20,10))
plt.scatter(data["FIRST_ASSIGNMENT_DATETIME"],data['INCIDENT_TRAVEL_TM_SECONDS_QY'])
plt.xlabel("FIRST_ASSIGNMENT_DATETIME")
plt.ylabel("INCIDENT_TRAVEL_TM_SECONDS")
plt.show()

# %%
plt.figure(figsize =(20,10))
plt.scatter((data["FIRST_ASSIGNMENT_DATETIME"].dt.hour+data["FIRST_ASSIGNMENT_DATETIME"].dt.minute/60+(data["FIRST_ASSIGNMENT_DATETIME"].dt.second/60/100)
),data['INCIDENT_TRAVEL_TM_SECONDS_QY'])
plt.xlabel("Time Assigned (hr)")
plt.ylabel("INCIDENT_TRAVEL_TM_SECONDS")
plt.show()

# %% [markdown]
# ***INCIDENT TRAVEL TIME (all data)***

# %% [markdown]
# Incident travel times are comprised of many outliers. We will need to perform data reduction to get rid of some outliers without introducing bias in the model. We can look at the statistics produced based on boxplots. Deleting incidents with travel times > 2hrs does not change any of the statistics. There are only 296 incidents with > 2hrs travel times.

# %%
sns.boxplot(data['INCIDENT_TRAVEL_TM_SECONDS_QY'])

# %%
data['INCIDENT_TRAVEL_TM_SECONDS_QY'].describe()
# Out:
# count    2.911262e+06
# mean     4.901194e+02
# std      3.917800e+02
# min      0.000000e+00
# 25%      2.830000e+02
# 50%      4.060000e+02
# 75%      5.830000e+02
# max      8.738600e+04
# Name: INCIDENT_TRAVEL_TM_SECONDS_QY, dtype: float64

# %%
##calculating outliers; any travel times greater than this in seconds
data['INCIDENT_TRAVEL_TM_SECONDS_QY'].describe(include='all').loc['75%']+1.5*(data['INCIDENT_TRAVEL_TM_SECONDS_QY'].describe(include='all').loc['75%']-data['INCIDENT_TRAVEL_TM_SECONDS_QY'].describe(include='all').loc['25%'])
# Out:
# 1033.0

# %%
#Count num of instances that have travel response times > 1033 s (outliers)
data[data['INCIDENT_TRAVEL_TM_SECONDS_QY'] > 1033].count()['INCIDENT_TRAVEL_TM_SECONDS_QY']
# Out:
# 175061

# %% [markdown]
# ***Incident Travel Time (smaller window)***

# %%
sns.set(style = "whitegrid")
plt.xlim(-20,7200)
sns.boxplot(data['INCIDENT_TRAVEL_TM_SECONDS_QY'])

# %% [markdown]
# ***Incident Travel Time without T> 2hrs***

# %%
#Count num of instances that have travel response time greater than 2 hours
data[data['INCIDENT_TRAVEL_TM_SECONDS_QY'] > 7200].count()['INCIDENT_TRAVEL_TM_SECONDS_QY']
# Out:
# 296

# %%
#Drop rows where T>2hrs
t_condensed = data.drop(data[data['INCIDENT_TRAVEL_TM_SECONDS_QY'] > 7200].index)

# %%
#create series with just T>2hrs
t_condensed = t_condensed['INCIDENT_TRAVEL_TM_SECONDS_QY']

# %%
t_condensed.head()
# Out:
# 0    453.0
# 1    369.0
# 2    815.0
# 3    348.0
# 4    861.0
# Name: INCIDENT_TRAVEL_TM_SECONDS_QY, dtype: float64

# %%
#check if 296 rows were deleted
t_condensed.shape
# Out:
# (3001192,)

# %%
sns.set(style = "whitegrid")
plt.xlim(-20,7200)
sns.boxplot(t_condensed)

# %%
#deleting T>2hrs did not change distribution by much
t_condensed.describe()
# Out:
# count    2.910966e+06
# mean     4.890818e+02
# std      3.685603e+02
# min      0.000000e+00
# 25%      2.830000e+02
# 50%      4.050000e+02
# 75%      5.830000e+02
# max      7.195000e+03
# Name: INCIDENT_TRAVEL_TM_SECONDS_QY, dtype: float64

# %% [markdown]
# ***Incident Travel Time where T>2hr values occur***

# %% [markdown]
# Looking at where Incident travel times are >2hrs, it is very random - no specific patterns except some unusal behaviour on Nov 15, 2018. After further inspection, there was a significant snowstorm that day causing major delays.

# %%
t_outliers = data[data['INCIDENT_TRAVEL_TM_SECONDS_QY'] > 7200]

# %%
t_outliers.shape
# Out:
# (296, 36)

# %%
t_outliers.head()
# Out:
#        Unnamed: 0  CAD_INCIDENT_ID   INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 7613         7613        183640226 2018-12-30 01:06:15              SICK
# 8188         8188        183634004 2018-12-29 22:04:09               EDP
# 11264       11264        183630598 2018-12-29 03:40:27            SICMIN
# 11357       11357        183630494 2018-12-29 02:59:04              SICK
# 21993       21993        183602253 2018-12-26 14:05:26               EDP
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 7613                             6            SICK                          6
# 8188                             7             EDP                          7
# 11264                            7          SICMIN                          7
# 11357                            6            SICK                          6
# 21993                            7             EDP                          7
#
#       FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 7613        2018-12-30 01:07:08                              Y
# 8188        2018-12-29 22:20:36                              Y
# 11264       2018-12-29 03:41:03                              Y
# 11357       2018-12-29 03:02:47                              Y
# 21993       2018-12-26 14:12:25                              Y
#
#        DISPATCH_RESPONSE_SECONDS_QY  ... COMMUNITYSCHOOLDISTRICT  \
# 7613                             53  ...                    12.0
# 8188                            987  ...                    10.0
# 11264                            36  ...                     9.0
# 11357                           223  ...                    10.0
# 21993                           419  ...                    12.0
#
#       CONGRESSIONALDISTRICT REOPEN_INDICATOR  SPECIAL_EVENT_INDICATOR  \
# 7613                   15.0                N                        N
# 8188                   15.0                N                        N
# 11264                  15.0                N                        N
# 11357                  15.0                N                        N
# 21993                  15.0                N                        N
#
#        STANDBY_INDICATOR TRANSFER_INDICATOR Incident_Time Incident_Date  \
# 7613                   N                  N    12/30/2018   01:06:15 AM
# 8188                   N                  N    12/29/2018   10:04:09 PM
# 11264                  N                  N    12/29/2018   03:40:27 AM
# 11357                  N                  N    12/29/2018   02:59:04 AM
# 21993                  N                  N    12/26/2018   02:05:26 PM
#
#       Assignment_Date  Assignment_Time
# 7613       2018-12-30         01:07:08
# 8188       2018-12-29         22:20:36
# 11264      2018-12-29         03:41:03
# 11357      2018-12-29         03:02:47
# 21993      2018-12-26         14:12:25
#
# [5 rows x 36 columns]

# %%
plt.figure(figsize =(20,10))
plt.scatter(t_outliers["FIRST_ASSIGNMENT_DATETIME"],t_outliers['INCIDENT_TRAVEL_TM_SECONDS_QY'])

# %% [markdown]
# ***What is happening Nov 15, 2018?***

# %%
plt.figure(figsize =(8,4))
plt.scatter(t_outliers["FIRST_ASSIGNMENT_DATETIME"],t_outliers['INCIDENT_TRAVEL_TM_SECONDS_QY'])
plt.xlim('2018-11-14 00:00:00','2018-11-18 00:00:00')
# Out:
# (737012.0, 737016.0)

# %%
res = t_outliers.loc[(t_outliers["FIRST_ASSIGNMENT_DATETIME"]>'2018-11-14 00:00:00')&(t_outliers["FIRST_ASSIGNMENT_DATETIME"]<'2018-11-16 00:00:00') ]

# %%
res.head()
# Out:
#         Unnamed: 0  CAD_INCIDENT_ID   INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 186042      186042        183194424 2018-11-15 21:57:32            DIFFBR
# 186093      186093        183194363 2018-11-15 21:42:38              DRUG
# 186101      186101        183194353 2018-11-15 21:39:40              COLD
# 186327      186327        183194102 2018-11-15 20:43:30              SICK
# 186330      186330        183194098 2018-11-15 20:42:51              SICK
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 186042                            2          DIFFBR
# 186093                            4            DRUG
# 186101                            5          INJURY
# 186327                            6          DIFFBR
# 186330                            6            SICK
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 186042                          2       2018-11-15 22:00:08
# 186093                          4       2018-11-15 21:49:59
# 186101                          5       2018-11-15 22:02:57
# 186327                          2       2018-11-15 21:34:32
# 186330                          6       2018-11-15 20:43:28
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  ...  \
# 186042                              Y                           156  ...
# 186093                              Y                           441  ...
# 186101                              Y                          1397  ...
# 186327                              Y                          3062  ...
# 186330                              Y                            37  ...
#
#        COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT REOPEN_INDICATOR  \
# 186042                    12.0                  15.0                N
# 186093                    11.0                  14.0                N
# 186101                     6.0                  13.0                N
# 186327                     NaN                   NaN                N
# 186330                     6.0                  13.0                N
#
#         SPECIAL_EVENT_INDICATOR  STANDBY_INDICATOR TRANSFER_INDICATOR  \
# 186042                        N                  N                  N
# 186093                        N                  N                  N
# 186101                        N                  N                  N
# 186327                        N                  N                  N
# 186330                        N                  N                  N
#
#        Incident_Time Incident_Date Assignment_Date  Assignment_Time
# 186042    11/15/2018   09:57:32 PM      2018-11-15         22:00:08
# 186093    11/15/2018   09:42:38 PM      2018-11-15         21:49:59
# 186101    11/15/2018   09:39:40 PM      2018-11-15         22:02:57
# 186327    11/15/2018   08:43:30 PM      2018-11-15         21:34:32
# 186330    11/15/2018   08:42:51 PM      2018-11-15         20:43:28
#
# [5 rows x 36 columns]

# %%
import collections
from collections import Counter

# %% [markdown]
# ***TRAVEL TIME BINNED***

# %% [markdown]
# Further inspecting travel times, the data will need to be binned to view any useful trends. Binning the data every 5 min increment until 30min is useful. Based on statistics, any values > ~18min are considered to be outliers. It is still important to look at values up to ~30min which are still possibly valid. We can also group all incident travel times > 30min, and all nan values to see the distributions. We can look at the "global" distribution across NYC, and then the "local" distributions across each borough. Although we can see the distribution of travel times in each borough, it does not show us the corresponding severity level which is important to know if EMS reached the incident within a "reasonable" amount of time. We can plot each time travel bin with their corresponding initial severity level codes to see how they relate. We should expect lower initial severity levels (ie. 1,2..) to have much quicker travel times, and higher initial severity levels (ie. 7, 8, 9...) should have slower severity level times because EMS knew they were not to be prioritized over the more severe cases.

# %%
bins = [0,5*60,10*60,15*60,20*60,25*60,30*60,max(data['INCIDENT_TRAVEL_TM_SECONDS_QY'])]

# %%
labels = [1,2,3,4,5,6,7]

# %%
data["Travel_Time_Code"]=pd.cut(data['INCIDENT_TRAVEL_TM_SECONDS_QY'],bins=bins,labels=labels)

# %%
data.head()
# Out:
#    CAD_INCIDENT_ID   INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        183654386 2018-12-31 23:59:46            CARDBR
# 1        183654385 2018-12-31 23:59:20            MVAINJ
# 2        183654384 2018-12-31 23:58:45              SICK
# 3        183654383 2018-12-31 23:58:14            INJMAJ
# 4        183654382 2018-12-31 23:57:42               UNC
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            2          CARDBR                          2
# 1                            4          MVAINJ                          4
# 2                            6            SICK                          6
# 3                            3          INJMAJ                          3
# 4                            2             UNC                          2
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0       2018-12-31 23:59:54                              Y
# 1       2019-01-01 00:01:10                              Y
# 2       2019-01-01 00:00:43                              Y
# 3       2018-12-31 23:58:22                              Y
# 4       2019-01-01 00:00:39                              Y
#
#    DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT  \
# 0                             8    01/01/2019 12:00:51 AM  ...           84.0
# 1                           110    01/01/2019 12:02:25 AM  ...          102.0
# 2                           118    01/01/2019 12:02:08 AM  ...          115.0
# 3                             8    12/31/2018 11:58:37 PM  ...           62.0
# 4                           177    01/01/2019 12:01:03 AM  ...           18.0
#
#   CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT  \
# 0                35.0              302.0                     13.0
# 1                32.0              409.0                     27.0
# 2                21.0              480.0                     30.0
# 3                47.0              311.0                     20.0
# 4                 4.0              105.0                      2.0
#
#   CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 0                   8.0                N                       N
# 1                   7.0                N                       N
# 2                  14.0                N                       N
# 3                  11.0                N                       N
# 4                  12.0                N                       N
#
#   STANDBY_INDICATOR  TRANSFER_INDICATOR Travel_Time_Code
# 0                 N                   N                2
# 1                 N                   N                2
# 2                 N                   N                3
# 3                 N                   N                2
# 4                 N                   N                3
#
# [5 rows x 32 columns]

# %% [markdown]
# ***ALL NYC***

# %%
travel_nyc = collections.Counter(data["Travel_Time_Code"])
tot_travel_nyc = sum(travel_nyc.values()) #counts of each travel time code
travel_nyc = sorted(travel_nyc.items()) #sort so it lines up with the labels
travel_nyc
# Out:
# [(1, 803125),
#  (2, 1396730),
#  (3, 431656),
#  (4, 133136),
#  (5, 54959),
#  (6, 25863),
#  (7, 35717),
#  (nan, 120302)]

# %%
bars = ("0-5","5-10","10-15","15-20","20-25","25-30",">30","nan")
y_pos = np.arange(len(bars))

fig, ax = plt.subplots(figsize = (6,4))
idx = np.asarray([i for i in range(len(bins))])

ax.bar(idx, [x[1]*100/tot_travel_nyc for x in travel_nyc], width=width)
ax.set_xticks(idx)
ax.set_xticklabels(bars, rotation=65)
ax.set_xlabel('Incident Travel Time (min)')
ax.set_ylabel('Frequency (%)')
plt.title("All NYC - Incident Travel Times")

plt.show()

# %%
travel_nyc_code = data.groupby(["Travel_Time_Code","INITIAL_SEVERITY_LEVEL_CODE"]).size()
travel_nyc_code_sum = travel_nyc_code.groupby(level=[0]).sum().sort_values(ascending=False).sort_index(axis=0)
travel_nyc_code.reindex(index=travel_nyc_code_sum.index, level=0).unstack().plot.bar(stacked=True, cmap=cmp)
plt.legend(loc=1)
plt.show()

# %% [markdown]
# ***Brooklyn***

# %%
travel_bk = collections.Counter(data[data["BOROUGH"]=="BROOKLYN"].Travel_Time_Code)
tot_travel_bk = sum(travel_bk.values())
travel_bk = sorted(travel_bk.items())
travel_bk.append(travel_bk.pop(-2)) #move nan row to end
travel_bk
# Out:
# [(1, 218042),
#  (2, 391009),
#  (3, 125891),
#  (4, 40788),
#  (5, 17026),
#  (6, 7932),
#  (7, 10144),
#  (nan, 28504)]

# %%
bars = ("0-5","5-10","10-15","15-20","20-25","25-30",">30","nan")
y_pos = np.arange(len(bars))

fig, ax = plt.subplots(figsize = (6,4))
idx = np.asarray([i for i in range(len(bins))])

ax.bar(idx, [x[1] for x in travel_bk], width=width)
ax.set_xticks(idx)
ax.set_xticklabels(bars, rotation=65)
ax.set_xlabel('Incident Travel Time (min)')
ax.set_ylabel('Number of Incidents')
plt.title("Brooklyn - Incident Travel Times")

plt.show()

# %%
travel_bk_code = data.loc[data["BOROUGH"]=="BROOKLYN"] #filter specifically for rows only with BK first
travel_bk_code = travel_bk_code.groupby(["Travel_Time_Code","INITIAL_SEVERITY_LEVEL_CODE"]).size()
travel_bk_code_sum = travel_bk_code.groupby(level=[0]).sum().sort_values(ascending=False).sort_index(axis=0)
travel_bk_code.reindex(index=travel_bk_code_sum.index, level=0).unstack().plot.bar(stacked=True, cmap=cmp)
plt.legend(loc=1)
plt.show()

# %% [markdown]
# ***Bronx***

# %%
travel_brx = collections.Counter(data[data["BOROUGH"]=="BRONX"].Travel_Time_Code)
tot_travel_brx = sum(travel_brx.values())
travel_brx = sorted(travel_brx.items())
travel_brx
# Out:
# [(1, 165854),
#  (2, 328601),
#  (3, 111556),
#  (4, 34876),
#  (5, 14630),
#  (6, 6935),
#  (7, 9424),
#  (nan, 26660)]

# %%
bars = ("0-5","5-10","10-15","15-20","20-25","25-30",">30","nan")
y_pos = np.arange(len(bars))

fig, ax = plt.subplots(figsize = (6,4))
idx = np.asarray([i for i in range(len(bins))])

ax.bar(idx, [x[1] for x in travel_brx], width=width)
ax.set_xticks(idx)
ax.set_xticklabels(bars, rotation=65)
ax.set_xlabel('Incident Travel Time (min)')
ax.set_ylabel('Frequency (%)')
plt.title("Bronx - Incident Travel Times")

plt.show()

# %%
travel_brx_code = data.loc[data["BOROUGH"]=="BRONX"] #filter specifically for rows only with BK first
travel_brx_code = travel_brx_code.groupby(["Travel_Time_Code","INITIAL_SEVERITY_LEVEL_CODE"]).size()
travel_brx_code_sum = travel_brx_code.groupby(level=[0]).sum().sort_values(ascending=False).sort_index(axis=0)
travel_brx_code.reindex(index=travel_brx_code_sum.index, level=0).unstack().plot.bar(stacked=True, cmap=cmp)
plt.legend(loc=1)
plt.show()

# %% [markdown]
# ***Manhattan***

# %%
travel_mht = collections.Counter(data[data["BOROUGH"]=="MANHATTAN"].Travel_Time_Code)
tot_travel_mht = sum(travel_mht.values())
travel_mht = sorted(travel_mht.items())
travel_mht
# Out:
# [(1, 214542),
#  (2, 326461),
#  (3, 106914),
#  (4, 36988),
#  (5, 16476),
#  (6, 8269),
#  (7, 13346),
#  (nan, 39684)]

# %%
bars = ("0-5","5-10","10-15","15-20","20-25","25-30",">30","nan")
y_pos = np.arange(len(bars))

fig, ax = plt.subplots(figsize = (6,4))
idx = np.asarray([i for i in range(len(bins))])

ax.bar(idx, [x[1] for x in travel_mht], width=width)
ax.set_xticks(idx)
ax.set_xticklabels(bars, rotation=65)
ax.set_xlabel('Incident Travel Time (min)')
ax.set_ylabel('Frequency (%)')
plt.title("Manhattan - Incident Travel Times")

plt.show()

# %%
travel_mht_code = data.loc[data["BOROUGH"]=="MANHATTAN"] #filter specifically for rows only with BK first
travel_mht_code = travel_mht_code.groupby(["Travel_Time_Code","INITIAL_SEVERITY_LEVEL_CODE"]).size()
travel_mht_code_sum = travel_mht_code.groupby(level=[0]).sum().sort_values(ascending=False).sort_index(axis=0)
travel_mht_code.reindex(index=travel_mht_code_sum.index, level=0).unstack().plot.bar(stacked=True, cmap=cmp)
plt.legend(loc=1)
plt.show()

# %% [markdown]
# ***Queens***

# %%
travel_queens = collections.Counter(data[data["BOROUGH"]=="QUEENS"].Travel_Time_Code)
tot_travel_queens = sum(travel_queens.values())
travel_queens = sorted(travel_queens.items())
travel_queens.append(travel_queens.pop(-4)) #move nan row to end
travel_queens
# Out:
# [(1, 164500),
#  (2, 288820),
#  (3, 74276),
#  (4, 17467),
#  (5, 5900),
#  (6, 2341),
#  (7, 2440),
#  (nan, 21131)]

# %%
bars = ("0-5","5-10","10-15","15-20","20-25","25-30",">30","nan")
y_pos = np.arange(len(bars))

fig, ax = plt.subplots(figsize = (6,4))
idx = np.asarray([i for i in range(len(bins))])

ax.bar(idx, [x[1] for x in travel_queens], width=width)
ax.set_xticks(idx)
ax.set_xticklabels(bars, rotation=65)
ax.set_xlabel('Incident Travel Time (min)')
ax.set_ylabel('Frequency (%)')
plt.title("Queens - Incident Travel Times")

plt.show()

# %%
travel_queens_code = data.loc[data["BOROUGH"]=="QUEENS"] #filter specifically for rows only with BK first
travel_queens_code = travel_queens_code.groupby(["Travel_Time_Code","INITIAL_SEVERITY_LEVEL_CODE"]).size()
travel_queens_code_sum = travel_queens_code.groupby(level=[0]).sum().sort_values(ascending=False).sort_index(axis=0)
travel_queens_code.reindex(index=travel_queens_code_sum.index, level=0).unstack().plot.bar(stacked=True, cmap=cmp)
plt.legend(loc=1)
plt.show()

# %% [markdown]
# ***Staten Island***

# %%
travel_st = collections.Counter(data[data["BOROUGH"]=="RICHMOND / STATEN ISLAND"].Travel_Time_Code)
tot_travel_st = sum(travel_st.values())
travel_st = sorted(travel_st.items())
travel_st.append(travel_st.pop(-5)) #move nan row to end
travel_st
# Out:
# [(1, 40185),
#  (2, 61839),
#  (3, 13019),
#  (4, 3017),
#  (5, 927),
#  (6, 386),
#  (7, 359),
#  (nan, 4312)]

# %%
bars = ("0-5","5-10","10-15","15-20","20-25","25-30",">30","nan")
y_pos = np.arange(len(bars))

fig, ax = plt.subplots(figsize = (6,4))
idx = np.asarray([i for i in range(len(bins))])

ax.bar(idx, [x[1] for x in travel_st], width=width)
ax.set_xticks(idx)
ax.set_xticklabels(bars, rotation=65)
ax.set_xlabel('Incident Travel Time (min)')
ax.set_ylabel('Frequency (%)')
plt.title("Richmond / Staten Island - Incident Travel Times")

plt.show()

# %%
travel_st_code = data.loc[data["BOROUGH"]=="RICHMOND / STATEN ISLAND"] #filter specifically for rows only with BK first
travel_st_code = travel_st_code.groupby(["Travel_Time_Code","INITIAL_SEVERITY_LEVEL_CODE"]).size()
travel_st_code_sum = travel_st_code.groupby(level=[0]).sum().sort_values(ascending=False).sort_index(axis=0)
travel_st_code.reindex(index=travel_st_code_sum.index, level=0).unstack().plot.bar(stacked=True, cmap=cmp)
plt.legend(loc=1)
plt.show()

# %% [markdown]
# ***BOROUGH***

# %%
borough = collections.Counter(data["BOROUGH"])
tot_borough = sum(borough.values())

# %%
borough
# Out:
# Counter({'BROOKLYN': 839336,
#          'QUEENS': 576875,
#          'MANHATTAN': 762680,
#          'BRONX': 698536,
#          'RICHMOND / STATEN ISLAND': 124044,
#          'UNKNOWN': 17})

# %%
borough = {k: (v*100) / tot_borough for k, v in borough.items()} #mult by 100 to turn into percent
plt.bar(borough.keys(),borough.values())
plt.grid(axis = 'x')
plt.xticks(rotation = 90)
plt.xlabel("Borough")
plt.ylabel("Frequency (%)")
plt.show()

# %% [markdown]
# ***INITAL SEVERITY LEVEL***

# %%
severity_initial = collections.Counter(data["INITIAL_SEVERITY_LEVEL_CODE"])
tot_severity_initial = sum(severity_initial.values())

# %%
severity_initial
# Out:
# Counter({2: 634675,
#          4: 595233,
#          6: 485649,
#          3: 378169,
#          7: 364029,
#          5: 492668,
#          1: 42078,
#          8: 8959,
#          9: 28})

# %%
severity_initial = {k: (v*100) / tot_severity_initial for k, v in severity_initial.items()}#mult by 100 to turn into perc
plt.bar(severity_initial.keys(),severity_initial.values())
plt.grid(axis = 'x')
plt.xlabel("Initial Severity Level")
plt.xticks(np.arange(1,10))
plt.ylabel("Frequency (%)")
plt.show()

# %% [markdown]
# ***INCIDENT DISPOSITIONS***

# %%
from math import isnan
disp = collections.Counter(data["INCIDENT_DISPOSITION_CODE"])
tot_disp = sum(disp.values())

# %%
disp
# Out:
# Counter({82.0: 2089937,
#          91.0: 49963,
#          93.0: 367002,
#          90.0: 271702,
#          96.0: 110753,
#          nan: 1,
#          nan: 1,
#          87.0: 69166,
#          83.0: 20439,
#          nan: 1,
#          nan: 1,
#          94.0: 2318,
#          95.0: 298,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          92.0: 23,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          ...})

# %%
disp = {k: (v*100) / tot_disp for k, v in disp.items()}#mult by 100 to turn into percent
plt.bar(disp.keys(),disp.values())
plt.grid(axis = 'x')
plt.xticks([82,83,87,90,91,92,93,94,95,96])
plt.xlabel("Incident Disposition Code")
plt.ylabel("Frequency (%)")
plt.show()

# %% [markdown]
# ***HELD_INDICATOR***

# %%
held_ind = collections.Counter(data["HELD_INDICATOR"])
tot_held_ind = sum(held_ind.values())
held_ind
# Out:
# Counter({'N': 2855023, 'Y': 146465})

# %%
tot_held_ind
# Out:
# 3001488

# %%
held_ind = {k: (v*100) / tot_held_ind for k, v in held_ind.items()}#mult by 100 to turn into percent
plt.bar(held_ind.keys(),held_ind.values())
plt.grid(axis = 'x')
plt.xlabel("Held Indicator")
plt.ylabel("Frequency (%)")
plt.show()

# %% [markdown]
# ***STANDBY_INDICATOR***

# %%
stby_ind = collections.Counter(data["STANDBY_INDICATOR"])
tot_stby_ind = sum(stby_ind.values())
stby_ind
# Out:
# Counter({'N': 2993558, 'Y': 7930})

# %%
tot_stby_ind
# Out:
# 3001488

# %%
stby_ind = {k: (v*100) / tot_stby_ind for k, v in stby_ind.items()}#mult by 100 to turn into percent
plt.bar(stby_ind.keys(),stby_ind.values())
plt.grid(axis = 'x')
plt.xlabel("Standby Indicator")
plt.ylabel("Frequency (%)")
plt.show()

# %% [markdown]
# ***SPECIAL EVENT INDICATOR***

# %%
spevent_ind = collections.Counter(data["SPECIAL_EVENT_INDICATOR"])
tot_spevent_ind = sum(spevent_ind.values())
spevent_ind
# Out:
# Counter({'N': 3001257, 'Y': 231})

# %%
tot_spevent_ind
# Out:
# 3001488

# %%
spevent_ind = {k: (v*100) / tot_spevent_ind for k, v in spevent_ind.items()}#mult by 100 to turn into percent
plt.bar(spevent_ind.keys(),spevent_ind.values())
plt.grid(axis = 'x')
plt.xlabel("Special Event Indicator")
plt.ylabel("Frequency (%)")
plt.show()

# %% [markdown]
# ***INCIDENT DISPATCH AREA***

# %%
disp_area = collections.Counter(data["INCIDENT_DISPATCH_AREA"])
tot_disp_area = sum(disp_area.values())
disp_area
# Out:
# Counter({'K6': 102541,
#          'Q3': 65195,
#          'Q6': 156625,
#          'K1': 127004,
#          'M3': 148227,
#          'K4': 207034,
#          'Q5': 33275,
#          'B3': 137203,
#          'Q1': 42279,
#          'B2': 211093,
#          'K5': 78454,
#          'M1': 90028,
#          'K7': 123081,
#          'S1': 62190,
#          'Q2': 156051,
#          'B1': 174583,
#          'K3': 94897,
#          'B4': 82405,
#          'K2': 106911,
#          'M8': 40384,
#          'M4': 59578,
#          'M2': 142253,
#          'M5': 79599,
#          'M7': 92325,
#          'Q7': 66910,
#          'M9': 84105,
#          'B5': 92904,
#          'S3': 15509,
#          'Q4': 55953,
#          'M6': 25574,
#          'S2': 46220,
#          'X1': 460,
#          'CW': 613,
#          'X2': 14,
#          'X3': 3,
#          'X4': 2,
#          'X5': 3,
#          'C1': 1,
#          'BO': 2})

# %%
tot_disp_area
# Out:
# 3001488

# %%
disp_area = {k: (v*100) / tot_disp_area for k, v in disp_area.items()}#mult by 100 to turn into percent

plt.figure(figsize =(20,10))
plt.bar(disp_area.keys(),disp_area.values())
plt.grid(axis = 'x')
plt.xlabel("Incident Dispatch Area")
plt.ylabel("Frequency (%)")
plt.show()

# %% [markdown]
# ***MAPS***

# %%
test = data.groupby("ZIPCODE")["INCIDENT_RESPONSE_SECONDS_QY"].mean()

# %%
res = pd.DataFrame(test)

# %%
res = res.drop(res.index[0])

# %%
res.drop(res.tail(1).index,inplace=True)

# %%
test_time = res["INCIDENT_RESPONSE_SECONDS_QY"].tolist()

# %%
test_index = res.index.tolist()

# %%
test_index
# Out:
# [10000.0,
#  10001.0,
#  10002.0,
#  10003.0,
#  10004.0,
#  10005.0,
#  10006.0,
#  10007.0,
#  10009.0,
#  10010.0,
#  10011.0,
#  10012.0,
#  10013.0,
#  10014.0,
#  10016.0,
#  10017.0,
#  10018.0,
#  10019.0,
#  10020.0,
#  10021.0,
#  10022.0,
#  10023.0,
#  10024.0,
#  10025.0,
#  10026.0,
#  10027.0,
#  10028.0,
#  10029.0,
#  10030.0,
#  10031.0,
#  10032.0,
#  10033.0,
#  10034.0,
#  10035.0,
#  10036.0,
#  10037.0,
#  10038.0,
#  10039.0,
#  10040.0,
#  10041.0,
#  10044.0,
#  10045.0,
#  10048.0,
#  10055.0,
#  10065.0,
#  10069.0,
#  10075.0,
#  10103.0,
#  10105.0,
#  10106.0,
#  10107.0,
#  10110.0,
#  10111.0,
#  10112.0,
#  10115.0,
#  10118.0,
#  10119.0,
#  10120.0,
#  10121.0,
#  10122.0,
#  10123.0,
#  10128.0,
#  10129.0,
#  10151.0,
#  10152.0,
#  10153.0,
#  10154.0,
#  10155.0,
#  10158.0,
#  10162.0,
#  10165.0,
#  10167.0,
#  10168.0,
#  10169.0,
#  10170.0,
#  10171.0,
#  10172.0,
#  10173.0,
#  10174.0,
#  10175.0,
#  10176.0,
#  10177.0,
#  10178.0,
#  10179.0,
#  10271.0,
#  10278.0,
#  10279.0,
#  10280.0,
#  10281.0,
#  10282.0,
#  10301.0,
#  10302.0,
#  10303.0,
#  10304.0,
#  10305.0,
#  10306.0,
#  10307.0,
#  10308.0,
#  10309.0,
#  10310.0,
#  10312.0,
#  10314.0,
#  10451.0,
#  10452.0,
#  10453.0,
#  10454.0,
#  10455.0,
#  10456.0,
#  10457.0,
#  10458.0,
#  10459.0,
#  10460.0,
#  10461.0,
#  10462.0,
#  10463.0,
#  10464.0,
#  10465.0,
#  10466.0,
#  10467.0,
#  10468.0,
#  10469.0,
#  10470.0,
#  10471.0,
#  10472.0,
#  10473.0,
#  10474.0,
#  10475.0,
#  10803.0,
#  11001.0,
#  11004.0,
#  11005.0,
#  11040.0,
#  11101.0,
#  11102.0,
#  11103.0,
#  11104.0,
#  11105.0,
#  11106.0,
#  11109.0,
#  11201.0,
#  11203.0,
#  11204.0,
#  11205.0,
#  11206.0,
#  11207.0,
#  11208.0,
#  11209.0,
#  11210.0,
#  11211.0,
#  11212.0,
#  11213.0,
#  11214.0,
#  11215.0,
#  11216.0,
#  11217.0,
#  11218.0,
#  11219.0,
#  11220.0,
#  11221.0,
#  11222.0,
#  11223.0,
#  11224.0,
#  11225.0,
#  11226.0,
#  11228.0,
#  11229.0,
#  11230.0,
#  11231.0,
#  11232.0,
#  11233.0,
#  11234.0,
#  11235.0,
#  11236.0,
#  11237.0,
#  11238.0,
#  11239.0,
#  11241.0,
#  11242.0,
#  11249.0,
#  11251.0,
#  11354.0,
#  11355.0,
#  11356.0,
#  11357.0,
#  11358.0,
#  11359.0,
#  11360.0,
#  11361.0,
#  11362.0,
#  11363.0,
#  11364.0,
#  11365.0,
#  11366.0,
#  11367.0,
#  11368.0,
#  11369.0,
#  11370.0,
#  11371.0,
#  11372.0,
#  11373.0,
#  11374.0,
#  11375.0,
#  11377.0,
#  11378.0,
#  11379.0,
#  11385.0,
#  11411.0,
#  11412.0,
#  11413.0,
#  11414.0,
#  11415.0,
#  11416.0,
#  11417.0,
#  11418.0,
#  11419.0,
#  11420.0,
#  11421.0,
#  11422.0,
#  11423.0,
#  11426.0,
#  11427.0,
#  11428.0,
#  11429.0,
#  11430.0,
#  11432.0,
#  11433.0,
#  11434.0,
#  11435.0,
#  11436.0,
#  11691.0,
#  11692.0,
#  11693.0,
#  11694.0,
#  11695.0,
#  11697.0]

# %%
pip install pyshp
# Out:
# Collecting pyshp
#   Downloading https://files.pythonhosted.org/packages/27/16/3bf15aa864fb77845fab8007eda22c2bd67bd6c1fd13496df452c8c43621/pyshp-2.1.0.tar.gz (215kB)
#      |████████████████████████████████| 225kB 4.3MB/s eta 0:00:01
# Building wheels for collected packages: pyshp
#   Building wheel for pyshp (setup.py) ... done
#   Stored in directory: /Users/amandakuznecov/Library/Caches/pip/wheels/a6/0c/de/321b5192ad416b328975a2f0385f72c64db4656501eba7cc1a
# Successfully built pyshp
# Installing collected packages: pyshp
# Successfully installed pyshp-2.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Downloading https://files.pythonhosted.org/packages/59/39/de0263d511d4fc35a640cf00d02e497eb60698315a22936bedbdd904d7f7/geopandas-0.6.1-py2.py3-none-any.whl (918kB)
#      |████████████████████████████████| 921kB 3.7MB/s eta 0:00:01
# Collecting fiona (from geopandas)
#   Downloading https://files.pythonhosted.org/packages/95/ee/80dd701ddf8e6b9407598ddf7690a5efcb7ea44850f2a5513b46c572b918/Fiona-1.8.11-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (17.9MB)
#      |████████████████████████████████| 17.9MB 17.7MB/s eta 0:00:01
# Collecting pyproj (from geopandas)
#   Downloading https://files.pythonhosted.org/packages/92/4b/d282d3cab551196270886302079b083380f2b3922b1320b16a88c0c8d50d/pyproj-2.4.1-cp37-cp37m-macosx_10_6_intel.whl (13.4MB)
#      |████████████████████████████████| 13.4MB 23.0MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.23.0 in /anaconda3/lib/python3.7/site-packages (from geopandas) (0.24.2)
# Collecting shapely (from geopandas)
#   Downloading https://files.pythonhosted.org/packages/1e/32/9d1cbfdc94864282be7745a7f7679ca16beb12ec5d71efd12a3f6cc0690a/Shapely-1.6.4.post2-cp37-cp37m-macosx_10_9_x86_64.whl (1.6MB)
#      |████████████████████████████████| 1.6MB 15.6MB/s eta 0:00:01
# Requirement already satisfied: six>=1.7 in /anaconda3/lib/python3.7/site-packages (from fiona->geopandas) (1.12.0)
# Collecting munch (from fiona->geopandas)
#   Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Collecting cligj>=0.5 (from fiona->geopandas)
#   Downloading https://files.pythonhosted.org/packages/e4/be/30a58b4b0733850280d01f8bd132591b4668ed5c7046761098d665ac2174/cligj-0.5.0-py3-none-any.whl
# Requirement already satisfied: click<8,>=4.0 in /anaconda3/lib/python3.7/site-packages (from fiona->geopandas) (7.0)
# Requirement already satisfied: attrs>=17 in /anaconda3/lib/python3.7/site-packages (from fiona->geopandas) (19.1.0)
# Collecting click-plugins>=1.0 (from fiona->geopandas)
#   Downloading https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.12.0 in /anaconda3/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas) (1.16.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in /anaconda3/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas) (2.8.0)
# Requirement already satisfied: pytz>=2011k in /anaconda3/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas) (2019.1)
# Installing collected packages: munch, cligj, click-plugins, fiona, pyproj, shapely, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.5.0 fiona-1.8.11 geopandas-0.6.1 munch-2.5.0 pyproj-2.4.1 shapely-1.6.4.post2
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install descartes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: //anaconda3
#
#   added / updated specs:
#     - descartes
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.7.12               |           py37_0         3.0 MB
#     descartes-1.1.0            |             py_3           9 KB
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   descartes          pkgs/main/noarch::descartes-1.1.0-py_3
#
# The following packages will be UPDATED:
#
#   conda                                       4.7.10-py37_0 --> 4.7.12-py37_0
#
#
#
# Downloading and Extracting Packages
# conda-4.7.12         | 3.0 MB    | ##################################### | 100%
# descartes-1.1.0      | 9 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import shapefile as shp
import geopandas as gpd
# %matplotlib inline

# %%
sf = shp.Reader('ZIP_CODE_040114.shp')

# %%
len(sf.shapes())
# Out:
# 263

# %%
sf.records()[1]
# Out:
# Record #1: ['11213', '0', 'Brooklyn', 62426.0, 29631004.437939, 'NY', 'Kings', '36', '047', 'http://www.usps.com/', 0.0, 0.0]

# %%
#used from Towards Data Science blog post, https://towardsdatascience.com/mapping-geograph-data-in-python-610a963d2d7f
def read_shapefile(sf):
    fields = [x[0] for x in sf.fields][1:]
    records = sf.records()
    shps = [s.points for s in sf.shapes()]
    df = pd.DataFrame(columns=fields, data=records)
    df = df.assign(coords=shps)
    return df

# %%
df = read_shapefile(sf)
df.shape
# Out:
# (263, 13)

# %%
df.sample(10)
# Out:
#     ZIPCODE BLDGZIP        PO_NAME  POPULATION          AREA STATE    COUNTY  \
# 197   10069       0       New York      5850.0  2.372366e+06    NY  New York
# 168   11366       0  Fresh Meadows     13168.0  2.035859e+07    NY    Queens
# 190   10154       1       New York         0.0  7.914880e+04    NY  New York
# 103   11412       0   Saint Albans     35019.0  4.584275e+07    NY    Queens
# 62    10028       0       New York     47530.0  9.842046e+06    NY  New York
# 66    10021       0       New York     45299.0  1.049513e+07    NY  New York
# 2     11212       0       Brooklyn     83866.0  4.197210e+07    NY     Kings
# 132   11234       0       Brooklyn     85853.0  2.062010e+08    NY     Kings
# 212   10103       1       New York         0.0  6.271325e+04    NY  New York
# 122   11215       0       Brooklyn     63272.0  6.192282e+07    NY     Kings
#
#     ST_FIPS CTY_FIPS                   URL  SHAPE_AREA  SHAPE_LEN  \
# 197      36      061  http://www.usps.com/         0.0        0.0
# 168      36      081  http://www.usps.com/         0.0        0.0
# 190      36      061  http://www.usps.com/         0.0        0.0
# 103      36      081  http://www.usps.com/         0.0        0.0
# 62       36      061  http://www.usps.com/         0.0        0.0
# 66       36      061  http://www.usps.com/         0.0        0.0
# 2        36      047  http://www.usps.com/         0.0        0.0
# 132      36      047  http://www.usps.com/         0.0        0.0
# 212      36      061  http://www.usps.com/         0.0        0.0
# 122      36      047  http://www.usps.com/         0.0        0.0
#
#                                                 coords
# 197  [(987514.9658991396, 223898.30586205423), (987...
# 168  [(1047964.5215089768, 205966.9598350525), (104...
# 190  [(991907.6877567321, 215231.51184396446), (991...
# 103  [(1053433.7822239846, 196458.55726397038), (10...
# 62   [(995349.451214388, 224260.552840963), (995377...
# 66   [(998204.3503602296, 218909.33847780526), (997...
# 2    [(1011174.275535807, 183696.33770971), (101137...
# 132  [(1002458.9560242295, 170567.6008438766), (100...
# 212  [(990555.1740575582, 216366.9354261309), (9905...
# 122  [(987432.7213129848, 186853.15915197134), (987...

# %%
#used from Towards Data Science blog post, https://towardsdatascience.com/mapping-geograph-data-in-python-610a963d2d7f
    
def plot_map(sf, x_lim = None, y_lim = None, figsize = (11,9)):
    '''
    Plot map with lim coordinates
    '''
    plt.figure(figsize = figsize)
    id=0
    for shape in sf.shapeRecords():
        x = [i[0] for i in shape.shape.points[:]]
        y = [i[1] for i in shape.shape.points[:]]
        plt.plot(x, y, 'k')
        
        if (x_lim == None) & (y_lim == None):
            x0 = np.mean(x)
            y0 = np.mean(y)
            plt.text(x0, y0, id, fontsize=10)
        id = id+1
    
    if (x_lim != None) & (y_lim != None):     
        plt.xlim(x_lim)
        plt.ylim(y_lim)

# %%
plot_map(sf)

# %%
def calc_color(data, color=None):
        if color   == 1: color_sq =  ['#dadaebFF','#bcbddcF0','#9e9ac8F0',
                        '#807dbaF0','#6a51a3F0','#54278fF0']; colors = 'Purples';
        elif color == 2: color_sq = ['#c7e9b4','#7fcdbb','#41b6c4',
                        '#1d91c0','#225ea8','#253494']; colors = 'YlGnBu';
        elif color == 3: color_sq = ['#f7f7f7','#d9d9d9','#bdbdbd',
                        '#969696','#636363','#252525']; colors = 'Greys';
        elif color == 9: color_sq = ['#ff0000','#ff0000','#ff0000',
                        '#ff0000','#ff0000','#ff0000']
        else:            color_sq = ['#ffffd4','#fee391','#fec44f',
                        '#fe9929','#d95f0e','#993404']; colors = 'YlOrBr';
        new_data, bins = pd.qcut(data, 6, retbins=True, 
        labels=list(range(6)))
        color_ton = []
        for val in new_data:
            color_ton.append(color_sq[val]) 
        if color != 9:
            colors = sns.color_palette(colors, n_colors=6)
            sns.palplot(colors, 0.6);
            for i in range(6):
                print ("\n"+str(i+1)+': '+str(int(bins[i]))+
                       " => "+str(int(bins[i+1])-1), end =" ")
            print("\n\n   1   2   3   4   5   6")    
        return (color_ton, bins)

# %%
def plot_map_fill_multiples_ids_tone(sf, title, comuna,  
                                     print_id, color_ton, 
                                     bins, 
                                     x_lim = None, 
                                     y_lim = None, 
                                     figsize = (11,9)):
    '''
    Plot map with lim coordinates
    '''
        
    plt.figure(figsize = figsize)
    fig, ax = plt.subplots(figsize = figsize)
    fig.suptitle(title, fontsize=16)
    for shape in sf.shapeRecords():
        x = [i[0] for i in shape.shape.points[:]]
        y = [i[1] for i in shape.shape.points[:]]
        ax.plot(x, y, 'k')
            
    for id in comuna:
        shape_ex = sf.shape(id)
        x_lon = np.zeros((len(shape_ex.points),1))
        y_lat = np.zeros((len(shape_ex.points),1))
        for ip in range(len(shape_ex.points)):
            x_lon[ip] = shape_ex.points[ip][0]
            y_lat[ip] = shape_ex.points[ip][1]
        ax.fill(x_lon,y_lat, color_ton[comuna.index(id)])
        if print_id != False:
            x0 = np.mean(x_lon)
            y0 = np.mean(y_lat)
            plt.text(x0, y0, id, fontsize=10)
    if (x_lim != None) & (y_lim != None):     
        plt.xlim(x_lim)
        plt.ylim(y_lim)

# %%
def plot_zipcode_data(sf, title, zipcode, data=None, color=None, print_id=False):

    color_ton, bins = calc_color(data, color)
    df = read_shapefile(sf)
    zipcode_id = []
    for i in zipcode:
        zipcode_id.append(df[df.ZIPCODE == i].index.get_values()[0])
    plot_map_fill_multiples_ids_tone(sf, title, zipcode_id, print_id, color_ton, bins, x_lim = None, y_lim = None, figsize = (11,9))

# %%
zipcode_id = []
for i in test_index:
    zipcode_id.append(df[df.ZIPCODE == i].index.get_values()[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-971-420b12e697b2> in <module>
#       1 zipcode_id = []
#       2 for i in test_index:
# ----> 3     zipcode_id.append(df[df.ZIPCODE == i].index.get_values()[0])
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
df[df.ZIPCODE == "10005"].index.get_values()[0]
# Out:
# 104

# %%
print_id = True
color_pallete = 1

# %%
plot_zipcode_data(sf, 'NYC', test_index, test_time, color_pallete, print_id)
# Out:
# 1: 233 => 453
# 2: 454 => 503
# 3: 504 => 549
# 4: 550 => 598
# 5: 599 => 659
# 6: 660 => 1156
#
#    1   2   3   4   5   6
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-968-a26b0768f1f1> in <module>
# ----> 1 plot_zipcode_data(sf, 'NYC', test_index, test_time, color_pallete, print_id)
#
# <ipython-input-967-6c7f9c1adece> in plot_zipcode_data(sf, title, zipcode, data, color, print_id)
#       5     zipcode_id = []
#       6     for i in zipcode:
# ----> 7         zipcode_id.append(df[df.ZIPCODE == i].index.get_values()[0])
#       8     plot_map_fill_multiples_ids_tone(sf, title, zipcode_id, print_id, color_ton, bins, x_lim = None, y_lim = None, figsize = (11,9))
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
