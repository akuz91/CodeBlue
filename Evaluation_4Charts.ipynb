# %%
RF5 = [.7,.8384, .8624, .8872, .91072]
RF12 = [.52, .6352, .6876, .71488, .75048]
RF25 = [.24, .3872, .3756, .46304, .48808]
RF41 = [.104, .1792, .2096, .2824, .31272]

# %%
ADA5 = [0.884, 0.8904 ,0.8756 ,0.86336 , 0.97672]
ADA12 = [0.828,0.8288 ,0.814 ,0.78736 , 0.81224]
ADA25 = [0.516,0.5704 ,0.4732 ,0.63872 , 0.75684]
ADA41 = [0.412,0.4368 ,0.4072 ,0.4296 , 0.62224]

# %%
LDA5 = [0.708, 0.8592, 0.9012, 0.91856, 0.9356]
LDA12 = [0.54, 0.7768, 0.8344, 0.86176, 0.86232]
LDA25 = [0.364, 0.5856, 0.6528, 0.69136, 0.71176]
LDA41= [0.244, 0.3792, 0.4384, 0.50912, 0.5392]

# %%
KNN5 = [0.924, 0.9472, 0.9516, 0.94192, 0.94904]
KNN12 = [0.864, 0.8568, 0.8708, 0.88448, 0.87616]
KNN25 = [0.716, 0.7168, 0.7492, 0.73968, 0.74248]
KNN41 = [0.576, 0.632, 0.6088, 0.61664, 0.62136]

# %%
LR5 = [0.632, 0.6832, 0.7176, 0.75936, 0.7696]
LR12 = [0.324, 0.3312, 0.358, 0.36656, 0.40664]
LR25 = [0.128, 0.1512, 0.1668, 0.1744, 0.19808]
LR41 = [0.072, 0.0912, 0.0964, 0.1096, 0.11728]

# %%
SVM5 = [0.928, 0.9344, 0.9232, 0.93472, 0.94568]
SVM12 = [0.82, 0.8272, 0.8284, 0.85872, 0.86432]
SVM25 = [0.656, 0.6576, 0.6612, 0.68656, 0.70392]
SVM41 = [0.46, 0.4528, 0.4828, 0.52624, 0.55664]

# %%
frames = [RF5,RF12,RF25, RF41,ADA5,ADA12,ADA25, ADA41, LDA5,LDA12,LDA25, LDA41,KNN5,KNN12,KNN25, KNN41,
         LR5,LR12,LR25, LR41,SVM5,SVM12,SVM25, SVM41]

# %%
import pandas as pd

# %%
summary = pd.DataFrame(frames,columns = [1000,5000,10000,25000,50000])

# %%
summary.rename(index={0:"RF5",1:"RF12",2:"RF25", 3:"RF41",4:"ADA5",5:"ADA12",6:"ADA25", 
                      7:"ADA41", 8:"LDA5",9:"LDA12",10:"LDA25", 11:"LDA41",12:"KNN5",
                      13:"KNN12",14:"KNN25",15:"KNN41", 16: "LR5",17: "LR12",18: "LR25", 
                      19:"LR41",20:"SVM5",21:"SVM12",22:"SVM25", 23:"SVM41"}, inplace=True)

# %%
summary
# Out:
#        1000    5000    10000    25000    50000
# RF5    0.700  0.8384  0.8624  0.88720  0.91072
# RF12   0.520  0.6352  0.6876  0.71488  0.75048
# RF25   0.240  0.3872  0.3756  0.46304  0.48808
# RF41   0.104  0.1792  0.2096  0.28240  0.31272
# ADA5   0.884  0.8904  0.8756  0.86336  0.97672
# ADA12  0.828  0.8288  0.8140  0.78736  0.81224
# ADA25  0.516  0.5704  0.4732  0.63872  0.75684
# ADA41  0.412  0.4368  0.4072  0.42960  0.62224
# LDA5   0.708  0.8592  0.9012  0.91856  0.93560
# LDA12  0.540  0.7768  0.8344  0.86176  0.86232
# LDA25  0.364  0.5856  0.6528  0.69136  0.71176
# LDA41  0.244  0.3792  0.4384  0.50912  0.53920
# KNN5   0.924  0.9472  0.9516  0.94192  0.94904
# KNN12  0.864  0.8568  0.8708  0.88448  0.87616
# KNN25  0.716  0.7168  0.7492  0.73968  0.74248
# KNN41  0.576  0.6320  0.6088  0.61664  0.62136
# LR5    0.632  0.6832  0.7176  0.75936  0.76960
# LR12   0.324  0.3312  0.3580  0.36656  0.40664
# LR25   0.128  0.1512  0.1668  0.17440  0.19808
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bins5 = [RF5, ADA5,LDA5,KNN5,LR5,SVM5]

# %%
bins12 = [RF12, ADA12,LDA12,KNN12,LR12,SVM12]

# %%
bins25 = [RF25, ADA25,LDA25,KNN25,LR25,SVM25]

# %%
bins41 = [RF41, ADA41,LDA41,KNN41,LR41,SVM41]

# %%
df_5bins = pd.DataFrame(bins5,columns = [1000,5000,10000,25000,50000])
df_5bins.rename(index={0:"RF",1:"ADA",2:"LDA", 3:"KNN",4:"LR",5:"SVM"}, inplace=True)
df_5bins
# Out:
#      1000    5000    10000    25000    50000
# RF   0.700  0.8384  0.8624  0.88720  0.91072
# ADA  0.884  0.8904  0.8756  0.86336  0.97672
# LDA  0.708  0.8592  0.9012  0.91856  0.93560
# KNN  0.924  0.9472  0.9516  0.94192  0.94904
# LR   0.632  0.6832  0.7176  0.75936  0.76960
# SVM  0.928  0.9344  0.9232  0.93472  0.94568

# %%
df_12bins = pd.DataFrame(bins12,columns = [1000,5000,10000,25000,50000])
df_12bins.rename(index={0:"RF",1:"ADA",2:"LDA", 3:"KNN",4:"LR",5:"SVM"}, inplace=True)
df_12bins
# Out:
#      1000    5000    10000    25000    50000
# RF   0.520  0.6352  0.6876  0.71488  0.75048
# ADA  0.828  0.8288  0.8140  0.78736  0.81224
# LDA  0.540  0.7768  0.8344  0.86176  0.86232
# KNN  0.864  0.8568  0.8708  0.88448  0.87616
# LR   0.324  0.3312  0.3580  0.36656  0.40664
# SVM  0.820  0.8272  0.8284  0.85872  0.86432

# %%
df_25bins = pd.DataFrame(bins25,columns = [1000,5000,10000,25000,50000])
df_25bins.rename(index={0:"RF",1:"ADA",2:"LDA", 3:"KNN",4:"LR",5:"SVM"}, inplace=True)
df_25bins
# Out:
#      1000    5000    10000    25000    50000
# RF   0.240  0.3872  0.3756  0.46304  0.48808
# ADA  0.516  0.5704  0.4732  0.63872  0.75684
# LDA  0.364  0.5856  0.6528  0.69136  0.71176
# KNN  0.716  0.7168  0.7492  0.73968  0.74248
# LR   0.128  0.1512  0.1668  0.17440  0.19808
# SVM  0.656  0.6576  0.6612  0.68656  0.70392

# %%
df_41bins = pd.DataFrame(bins41,columns = [1000,5000,10000,25000,50000])
df_41bins.rename(index={0:"RF",1:"ADA",2:"LDA", 3:"KNN",4:"LR",5:"SVM"}, inplace=True)
df_41bins
# Out:
#      1000    5000    10000    25000    50000
# RF   0.104  0.1792  0.2096  0.28240  0.31272
# ADA  0.412  0.4368  0.4072  0.42960  0.62224
# LDA  0.244  0.3792  0.4384  0.50912  0.53920
# KNN  0.576  0.6320  0.6088  0.61664  0.62136
# LR   0.072  0.0912  0.0964  0.10960  0.11728
# SVM  0.460  0.4528  0.4828  0.52624  0.55664

# %%
fig, axes = plt.subplots(nrows=2, ncols=2,figsize=(15,10))
fig.suptitle('Learning Curves - All Models \n Sample Size vs Accuracy', fontsize=16)

df_5bins.transpose().plot(ax=axes[0,0],title = '5 Bins') #row=0, col=0
df_12bins.transpose().plot(ax=axes[1,0],title = '12 Bins') #row=1, col=0
df_25bins.transpose().plot(ax=axes[0,1],title = '25 Bins') #row=0, col=1
df_41bins.transpose().plot(ax=axes[1,1],title = '41 Bins') #row=1, col=1
plt.show()
plt.savefig('plots.png')
