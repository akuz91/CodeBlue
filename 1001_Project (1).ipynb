# %%
import numpy as np
import pandas as pd

# %%
import os

directory = os.getcwd()
data = pd.read_csv(directory + '/EMS_2017_2018.csv', sep=',') 
data = pd.DataFrame(data)

# %% [markdown]
# ## Heat map: Police precent Lat Long -
#
#
# ## add in the code names to original dataset for reference

# %%
data_wrk = data[['Incident_Date', 'Incident_Time', 'INITIAL_CALL_TYPE', 'INITIAL_SEVERITY_LEVEL_CODE', 'FINAL_CALL_TYPE', 'FINAL_SEVERITY_LEVEL_CODE', 'INCIDENT_TRAVEL_TM_SECONDS_QY', 'HELD_INDICATOR', 'INCIDENT_DISPOSITION_CODE', 'BOROUGH', 'ZIPCODE', 'POLICEPRECINCT', 'INCIDENT_DISPATCH_AREA']]

# %%
data_wrk
# Out:
#         Incident_Date Incident_Time INITIAL_CALL_TYPE  \
# 0         11:59:46 PM    12/31/2018            CARDBR
# 1         11:59:20 PM    12/31/2018            MVAINJ
# 2         11:58:45 PM    12/31/2018              SICK
# 3         11:58:14 PM    12/31/2018            INJMAJ
# 4         11:57:42 PM    12/31/2018               UNC
# 5         11:57:41 PM    12/31/2018            SICMIN
# 6         11:57:06 PM    12/31/2018            UNKNOW
# 7         11:57:04 PM    12/31/2018            CARDBR
# 8         11:55:49 PM    12/31/2018            INJURY
# 9         11:55:27 PM    12/31/2018            INJURY
# 10        11:55:23 PM    12/31/2018            ASTHMB
# 11        11:54:02 PM    12/31/2018              DRUG
# 12        11:53:51 PM    12/31/2018              DRUG
# 13        11:53:30 PM    12/31/2018              DRUG
# 14        11:53:23 PM    12/31/2018            UNKNOW
# 15        11:52:40 PM    12/31/2018            STATEP
# ...

# %% [markdown]
# # Cancelled call = NaN removed from original

# %%
a = data['INCIDENT_DISPOSITION_CODE'] != 'CANCEL'
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
a = data['INCIDENT_DISPOSITION_CODE'] != 'DUP'
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
a = data['INCIDENT_DISPOSITION_CODE'] != 87

# %%
a.describe()
# Out:
# count     3001488
# unique          2
# top          True
# freq      2932322
# Name: INCIDENT_DISPOSITION_CODE, dtype: object

# %%
3001487 - 2932322  #that were type 87
# Out:
# 69165

# %%
#87 H A S  B E E N  D R O P P E D 
data_wrk = data_wrk[data_wrk['INCIDENT_DISPOSITION_CODE'] != 87]

# %%
data_wrk.describe()
# Out:
#        INITIAL_SEVERITY_LEVEL_CODE  FINAL_SEVERITY_LEVEL_CODE  \
# count                 2.932322e+06               2.932322e+06
# mean                  4.260933e+00               4.165691e+00
# std                   1.720372e+00               1.720786e+00
# min                   1.000000e+00               1.000000e+00
# 25%                   3.000000e+00               3.000000e+00
# 50%                   4.000000e+00               4.000000e+00
# 75%                   6.000000e+00               6.000000e+00
# max                   9.000000e+00               8.000000e+00
#
#        INCIDENT_TRAVEL_TM_SECONDS_QY  INCIDENT_DISPOSITION_CODE       ZIPCODE  \
# count                   2.872968e+06               2.912435e+06  2.896174e+06
# mean                    4.896883e+02               8.483722e+01  1.073071e+04
# std                     3.898286e+02               4.706479e+00  5.497261e+02
# min                     0.000000e+00               8.200000e+01  8.300000e+01
# ...

# %%
data_wrk['Incident_Date']  #convert to panadas timseries
# Out:
# 0          11:59:46 PM
# 1          11:59:20 PM
# 2          11:58:45 PM
# 3          11:58:14 PM
# 4          11:57:42 PM
#               ...
# 3001482    12:02:05 AM
# 3001483    12:02:01 AM
# 3001484    12:01:27 AM
# 3001485    12:01:13 AM
# 3001487    12:01:03 AM
# Name: Incident_Date, Length: 2932322, dtype: object

# %%
data_wrk['Incident_Time']  #convert to panadas timseries
# Out:
# 0          12/31/2018
# 1          12/31/2018
# 2          12/31/2018
# 3          12/31/2018
# 4          12/31/2018
#               ...
# 3001482    01/01/2017
# 3001483    01/01/2017
# 3001484    01/01/2017
# 3001485    01/01/2017
# 3001487    01/01/2017
# Name: Incident_Time, Length: 2932322, dtype: object

# %%
data_wrk.isna().sum()
# Out:
# Incident_Date                        0
# Incident_Time                        0
# INITIAL_CALL_TYPE                    0
# INITIAL_SEVERITY_LEVEL_CODE          0
# FINAL_CALL_TYPE                      0
# FINAL_SEVERITY_LEVEL_CODE            0
# INCIDENT_TRAVEL_TM_SECONDS_QY    59354
# HELD_INDICATOR                       0
# INCIDENT_DISPOSITION_CODE        19887
# BOROUGH                              0
# ZIPCODE                          36148
# POLICEPRECINCT                   36055
# INCIDENT_DISPATCH_AREA               0
# dtype: int64

# %%
data_wrk[data_wrk.isna().any(axis=1)]
# Out:
#         Incident_Date Incident_Time INITIAL_CALL_TYPE  \
# 56        11:42:18 PM    12/31/2018            INJMIN
# 94        11:31:55 PM    12/31/2018            UNKNOW
# 110       11:26:33 PM    12/31/2018            MVAINJ
# 150       11:14:00 PM    12/31/2018              SICK
# 194       11:00:43 PM    12/31/2018             OTHER
# ...               ...           ...               ...
# 3001221   12:56:11 AM    01/01/2017            STNDBY
# 3001234   12:54:45 AM    01/01/2017              DRUG
# 3001411   12:19:31 AM    01/01/2017              SHOT
# 3001415   12:18:36 AM    01/01/2017            MVAINJ
# 3001440   12:11:34 AM    01/01/2017            MVAINJ
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 56                                 7          INJMIN
# 94                                 4          UNKNOW
# 110                                4          MVAINJ
# 150                                6            SICK
# ...

# %%
data.iloc[94]
# Out:
# Unnamed: 0                                              94
# CAD_INCIDENT_ID                                  183654276
# INCIDENT_DATETIME                   12/31/2018 11:31:55 PM
# INITIAL_CALL_TYPE                                   UNKNOW
# INITIAL_SEVERITY_LEVEL_CODE                              4
# FINAL_CALL_TYPE                                     UNKNOW
# FINAL_SEVERITY_LEVEL_CODE                                4
# FIRST_ASSIGNMENT_DATETIME                              NaN
# VALID_DISPATCH_RSPNS_TIME_INDC                           N
# DISPATCH_RESPONSE_SECONDS_QY                             0
# FIRST_ACTIVATION_DATETIME                              NaN
# FIRST_ON_SCENE_DATETIME                                NaN
# VALID_INCIDENT_RSPNS_TIME_INDC                           N
# INCIDENT_RESPONSE_SECONDS_QY                           NaN
# INCIDENT_TRAVEL_TM_SECONDS_QY                          NaN
# FIRST_TO_HOSP_DATETIME                                 NaN
# ...

# %%
data.iloc[56]
# Out:
# Unnamed: 0                                            56
# CAD_INCIDENT_ID                                183654316
# INCIDENT_DATETIME                 12/31/2018 11:42:18 PM
# INITIAL_CALL_TYPE                                 INJMIN
# INITIAL_SEVERITY_LEVEL_CODE                            7
# FINAL_CALL_TYPE                                   INJMIN
# FINAL_SEVERITY_LEVEL_CODE                              7
# FIRST_ASSIGNMENT_DATETIME         12/31/2018 11:42:41 PM
# VALID_DISPATCH_RSPNS_TIME_INDC                         Y
# DISPATCH_RESPONSE_SECONDS_QY                          23
# FIRST_ACTIVATION_DATETIME         12/31/2018 11:42:50 PM
# FIRST_ON_SCENE_DATETIME                              NaN
# VALID_INCIDENT_RSPNS_TIME_INDC                         N
# INCIDENT_RESPONSE_SECONDS_QY                         NaN
# INCIDENT_TRAVEL_TM_SECONDS_QY                        NaN
# FIRST_TO_HOSP_DATETIME                               NaN
# ...

# %%
a = data[data['INCIDENT_DISPOSITION_CODE'] == 96]

# %%
a.isna().sum()
# Out:
# Unnamed: 0                             0
# CAD_INCIDENT_ID                        0
# INCIDENT_DATETIME                      0
# INITIAL_CALL_TYPE                      0
# INITIAL_SEVERITY_LEVEL_CODE            0
# FINAL_CALL_TYPE                        0
# FINAL_SEVERITY_LEVEL_CODE              0
# FIRST_ASSIGNMENT_DATETIME              0
# VALID_DISPATCH_RSPNS_TIME_INDC         0
# DISPATCH_RESPONSE_SECONDS_QY           0
# FIRST_ACTIVATION_DATETIME            120
# FIRST_ON_SCENE_DATETIME             2683
# VALID_INCIDENT_RSPNS_TIME_INDC         0
# INCIDENT_RESPONSE_SECONDS_QY        2691
# INCIDENT_TRAVEL_TM_SECONDS_QY       2687
# FIRST_TO_HOSP_DATETIME            110661
# FIRST_HOSP_ARRIVAL_DATETIME       110683
# INCIDENT_CLOSE_DATETIME                0
# HELD_INDICATOR                         0
# INCIDENT_DISPOSITION_CODE              0
# BOROUGH                                0
# INCIDENT_DISPATCH_AREA                 0
# ZIPCODE                             1286
# ...

# %% [markdown]
# # Remove where disposition == 96 && INCIDENT_TRAVEL_TM_SECONDS_QY!= NaN

# %%
a.shape
# Out:
# (110753, 34)

# %%
data_wrk['INCIDENT_DISPATCH_AREA'].unique()
# Out:
# array(['K6', 'Q3', 'Q6', 'K1', 'M3', 'K4', 'Q5', 'B3', 'Q1', 'B2', 'K5',
#        'M1', 'K7', 'S1', 'Q2', 'B1', 'K3', 'B4', 'K2', 'M8', 'M4', 'M2',
#        'M5', 'M7', 'Q7', 'M9', 'B5', 'S3', 'Q4', 'M6', 'S2', 'X1', 'CW',
#        'X2', 'X3', 'X5', 'X4', 'C1', 'BO'], dtype=object)

# %% [markdown]
# # From whoel data mode of ^^^^^

# %%
data.iloc[296]
# Out:
# Unnamed: 0                                           299
# CAD_INCIDENT_ID                                183654050
# INCIDENT_DATETIME                 12/31/2018 10:33:43 PM
# INITIAL_CALL_TYPE                                  OTHER
# INITIAL_SEVERITY_LEVEL_CODE                            6
# FINAL_CALL_TYPE                                    OTHER
# FINAL_SEVERITY_LEVEL_CODE                              6
# FIRST_ASSIGNMENT_DATETIME                            NaN
# VALID_DISPATCH_RSPNS_TIME_INDC                         N
# DISPATCH_RESPONSE_SECONDS_QY                           0
# FIRST_ACTIVATION_DATETIME                            NaN
# FIRST_ON_SCENE_DATETIME                              NaN
# VALID_INCIDENT_RSPNS_TIME_INDC                         N
# INCIDENT_RESPONSE_SECONDS_QY                         NaN
# INCIDENT_TRAVEL_TM_SECONDS_QY                        NaN
# FIRST_TO_HOSP_DATETIME                               NaN
# ...

# %%
a = data_wrk[data_wrk['INCIDENT_DISPOSITION_CODE'] == 90.0]

# %%
a.isna().sum()
# Out:
# Incident_Date                       0
# Incident_Time                       0
# INITIAL_CALL_TYPE                   0
# INITIAL_SEVERITY_LEVEL_CODE         0
# FINAL_CALL_TYPE                     0
# FINAL_SEVERITY_LEVEL_CODE           0
# INCIDENT_TRAVEL_TM_SECONDS_QY    5668
# HELD_INDICATOR                      0
# INCIDENT_DISPOSITION_CODE           0
# BOROUGH                             0
# ZIPCODE                          6829
# POLICEPRECINCT                   6807
# INCIDENT_DISPATCH_AREA              0
# dtype: int64

# %%
data_wrk.shape
# Out:
# (2932322, 13)

# %%
(271702/2932322 )* 100
# Out:
# 9.265762764116628

# %%
(5668/2932322) * 100
# Out:
# 0.1932939151975806

# %%
data_wrk['FINAL_SEVERITY_LEVEL_CODE'].unique()
# Out:
# array([2, 4, 6, 3, 7, 5, 1, 8])

# %%
data_wrk['INITIAL_SEVERITY_LEVEL_CODE'].unique()
# Out:
# array([2, 4, 6, 3, 7, 5, 1, 8, 9])

# %%
a = data_wrk[data_wrk['INCIDENT_DISPOSITION_CODE'] == 90.0]

# %%
a
# Out:
#         Incident_Date Incident_Time INITIAL_CALL_TYPE  \
# 14        11:53:23 PM    12/31/2018            UNKNOW
# 32        11:48:11 PM    12/31/2018            UNKNOW
# 46        11:44:46 PM    12/31/2018              DRUG
# 52        11:42:56 PM    12/31/2018            UNKNOW
# 55        11:42:28 PM    12/31/2018            INJURY
# ...               ...           ...               ...
# 3001463   12:06:16 AM    01/01/2017            UNKNOW
# 3001473   12:04:05 AM    01/01/2017              DRUG
# 3001484   12:01:27 AM    01/01/2017              DRUG
# 3001485   12:01:13 AM    01/01/2017             OTHER
# 3001487   12:01:03 AM    01/01/2017              CARD
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 14                                 4          UNKNOW
# 32                                 4          UNKNOW
# 46                                 4            DRUG
# 52                                 4          UNKNOW
# ...

# %%
data.iloc[55]
# Out:
# Unnamed: 0                                            55
# CAD_INCIDENT_ID                                183654317
# INCIDENT_DATETIME                 12/31/2018 11:42:28 PM
# INITIAL_CALL_TYPE                                 INJURY
# INITIAL_SEVERITY_LEVEL_CODE                            5
# FINAL_CALL_TYPE                                   INJMAJ
# FINAL_SEVERITY_LEVEL_CODE                              3
# FIRST_ASSIGNMENT_DATETIME         12/31/2018 11:43:17 PM
# VALID_DISPATCH_RSPNS_TIME_INDC                         Y
# DISPATCH_RESPONSE_SECONDS_QY                          49
# FIRST_ACTIVATION_DATETIME         12/31/2018 11:43:30 PM
# FIRST_ON_SCENE_DATETIME           12/31/2018 11:53:03 PM
# VALID_INCIDENT_RSPNS_TIME_INDC                         Y
# INCIDENT_RESPONSE_SECONDS_QY                         635
# INCIDENT_TRAVEL_TM_SECONDS_QY                        586
# FIRST_TO_HOSP_DATETIME                               NaN
# ...

# %%
data_wrk['INITIAL_CALL_TYPE'].unique()
# Out:
# array(['CARDBR', 'MVAINJ', 'SICK', 'INJMAJ', 'UNC', 'SICMIN', 'UNKNOW',
#        'INJURY', 'ASTHMB', 'DRUG', 'STATEP', 'DIFFBR', 'SICPED', 'SEIZR',
#        'EDP', 'PEDSTR', 'INBLED', 'CARD', 'TRAUMA', 'INJMIN', 'ABDPN',
#        'ANAPH', 'GYNMAJ', 'OBLAB', 'CVAC', 'EDPC', 'STAB', 'JUMPUP',
#        'PD13', 'ALTMEN', 'OTHER', 'ARREST', 'MEDRXN', 'HYPTN', 'CHOKE',
#        'MVA', 'SHOT', 'OBMIS', 'GYNHEM', 'SAFE', 'RESPIR', 'INHALE',
#        'CVA', 'BURNMA', 'COLD', 'STNDBY', 'STRANS', 'OBMAJ', 'BURNMI',
#        'JUMPDN', 'OBCOMP', 'OBOUT', 'MCI21', 'DROWN', 'EDPW', 'AMPMIN',
#        'ACTIVE', 'CHILDA', 'SPEVNT', 'ELECT', 'MCI77', 'VENOM', 'MEDVAC',
#        'MVAINM', 'HEAT', 'DIFFFC', 'SICKFC', 'MCI76', 'MOSILL', 'AMPMAJ',
#        'PD13C', 'TRAUMS', 'BBP', 'MOSINJ', 'DOA', 'PEDFC', 'MCI22', 'ACC',
#        'CARDFC', 'ABDPFC', 'RESPFC', 'ASTHFC', 'NOVEH', 'STATFC',
#        'MEDRFC', 'UNCFC', 'ADM', 'PEDRF', 'MCI21P', 'MCI22P', 'CVAFC',
# ...

# %%
len(data_wrk['INITIAL_CALL_TYPE'].unique())
# Out:
# 105

# %%
data_wrk['FINAL_CALL_TYPE'].unique()
# Out:
# array(['CARDBR', 'MVAINJ', 'SICK', 'INJMAJ', 'UNC', 'SICMIN', 'UNKNOW',
#        'INJURY', 'ASTHMB', 'DRUG', 'STATEP', 'DIFFBR', 'SICPED', 'SEIZR',
#        'EDPC', 'PEDSTR', 'INBLED', 'CARD', 'EDP', 'TRAUMA', 'INJMIN',
#        'ABDPN', 'ANAPH', 'BURNMA', 'GYNMAJ', 'OBLAB', 'CVAC', 'STAB',
#        'ALTMEN', 'OTHER', 'ARREST', 'HYPTN', 'CHOKE', 'MVA', 'SHOT',
#        'OBMIS', 'MEDRXN', 'GYNHEM', 'SAFE', 'RESPIR', 'CVA', 'INHALE',
#        'PD13', 'COLD', 'MCI21', 'OBMAJ', 'STRANS', 'BURNMI', 'JUMPDN',
#        'MCI32', 'OBCOMP', 'JUMPUP', 'OBOUT', 'MCI22', 'MCI43', 'STNDBY',
#        'EDPW', 'DROWN', 'PD13C', 'ACTIVE', 'AMPMIN', 'CHILDA', 'SPEVNT',
#        'ELECT', 'MCI77', 'MEDVAC', 'HEAT', 'VENOM', 'MCI59', 'MCI23',
#        'AMPMAJ', 'MCI25', 'DIFFFC', 'MCI34', 'MCI80', 'SICKFC', 'MCI33',
#        'CARDFC', 'MCI76', 'DOA', 'MCI24', 'MCI35', 'MCI44', 'MCI38',
#        'PEDFC', 'MCI29', 'SICKRF', 'ABDPFC', 'RESPFC', 'ASTHFC', 'SEIZFC',
# ...

# %%
len(data_wrk['FINAL_CALL_TYPE'].unique())
# Out:
# 125

# %%
a = data_wrk[data_wrk['FINAL_CALL_TYPE'] == 'VENOM']

# %%
a.shape
# Out:
# (43, 13)

# %%
#take mode of zipcode from 'INCIDENT_DISPATCH_AREA' to replace all zipcode NaN

mv['ZIPCODE_mv'] = pd.DataFrame(data.groupby('INCIDENT_DISPATCH_AREA')['ZIPCODE'].apply(lambda x: x.value_counts().index[0]))

# %%
mv['PRECINCT_mv'] = pd.DataFrame(data.groupby('INCIDENT_DISPATCH_AREA')['POLICEPRECINCT'].apply(lambda x: x.value_counts().index[0]))

# %%
mv
# Out:
#                         ZIPCODE_mv  PRECINCT_mv
# INCIDENT_DISPATCH_AREA
# B1                         10456.0         40.0
# B2                         10457.0         44.0
# B3                         10472.0         43.0
# B4                         10467.0         47.0
# B5                         10468.0         52.0
# BO                         10452.0         44.0
# C1                         10461.0         49.0
# CW                         10035.0         25.0
# K1                         11235.0         60.0
# K2                         11220.0         68.0
# K3                         11203.0         67.0
# K4                         11207.0         75.0
# K5                         11216.0         77.0
# K6                         11201.0         84.0
# K7                         11206.0         83.0
# M1                         10002.0          1.0
# M2                         10003.0         13.0
# M3                         10019.0         14.0
# ...

# %%
mv_clean = data_wrk.merge(mv,on = 'INCIDENT_DISPATCH_AREA')
mv_clean
# Out:
#         Incident_Date Incident_Time INITIAL_CALL_TYPE  \
# 0         11:59:46 PM    12/31/2018            CARDBR
# 1         11:49:42 PM    12/31/2018               UNC
# 2         11:38:46 PM    12/31/2018               UNC
# 3         11:24:58 PM    12/31/2018              SICK
# 4         11:23:35 PM    12/31/2018            SICMIN
# 5         11:12:16 PM    12/31/2018               EDP
# 6         11:11:42 PM    12/31/2018               UNC
# 7         11:10:33 PM    12/31/2018            PEDSTR
# 8         11:08:20 PM    12/31/2018               EDP
# 9         11:06:25 PM    12/31/2018            INBLED
# 10        11:04:54 PM    12/31/2018              SICK
# 11        10:52:10 PM    12/31/2018              DRUG
# 12        10:46:37 PM    12/31/2018            MVAINJ
# 13        10:30:43 PM    12/31/2018               EDP
# 14        10:09:29 PM    12/31/2018            INJMAJ
# 15        10:08:50 PM    12/31/2018             SEIZR
# ...

# %%
mv_clean.loc[mv_clean['ZIPCODE'].isnull(),['ZIPCODE']] = mv_clean["ZIPCODE_mv"]
mv_clean.loc[mv_clean['POLICEPRECINCT'].isnull(),['POLICEPRECINCT']] = mv_clean["PRECINCT_mv"]

# %%
mv_clean
# Out:
#         Incident_Date Incident_Time INITIAL_CALL_TYPE  \
# 0         11:59:46 PM    12/31/2018            CARDBR
# 1         11:49:42 PM    12/31/2018               UNC
# 2         11:38:46 PM    12/31/2018               UNC
# 3         11:24:58 PM    12/31/2018              SICK
# 4         11:23:35 PM    12/31/2018            SICMIN
# 5         11:12:16 PM    12/31/2018               EDP
# 6         11:11:42 PM    12/31/2018               UNC
# 7         11:10:33 PM    12/31/2018            PEDSTR
# 8         11:08:20 PM    12/31/2018               EDP
# 9         11:06:25 PM    12/31/2018            INBLED
# 10        11:04:54 PM    12/31/2018              SICK
# 11        10:52:10 PM    12/31/2018              DRUG
# 12        10:46:37 PM    12/31/2018            MVAINJ
# 13        10:30:43 PM    12/31/2018               EDP
# 14        10:09:29 PM    12/31/2018            INJMAJ
# 15        10:08:50 PM    12/31/2018             SEIZR
# ...

# %%
mv_clean = mv_clean[mv_clean['INITIAL_CALL_TYPE'] != 'STNDBY']
mv_clean = mv_clean[mv_clean['ZIPCODE'] != 83]

# %%
mv_clean
# Out:
#         Incident_Date Incident_Time INITIAL_CALL_TYPE  \
# 0         11:59:46 PM    12/31/2018            CARDBR
# 1         11:49:42 PM    12/31/2018               UNC
# 2         11:38:46 PM    12/31/2018               UNC
# 3         11:24:58 PM    12/31/2018              SICK
# 4         11:23:35 PM    12/31/2018            SICMIN
# 5         11:12:16 PM    12/31/2018               EDP
# 6         11:11:42 PM    12/31/2018               UNC
# 7         11:10:33 PM    12/31/2018            PEDSTR
# 8         11:08:20 PM    12/31/2018               EDP
# 9         11:06:25 PM    12/31/2018            INBLED
# 10        11:04:54 PM    12/31/2018              SICK
# 11        10:52:10 PM    12/31/2018              DRUG
# 12        10:46:37 PM    12/31/2018            MVAINJ
# 13        10:30:43 PM    12/31/2018               EDP
# 14        10:09:29 PM    12/31/2018            INJMAJ
# 15        10:08:50 PM    12/31/2018             SEIZR
# ...

# %%
mv_clean['INCIDENT_TRAVEL_TM_SECONDS_QY'] = mv_clean['INCIDENT_TRAVEL_TM_SECONDS_QY'].replace(0,np.NaN)

# %%
mv_clean
# Out:
#         Incident_Date Incident_Time INITIAL_CALL_TYPE  \
# 0         11:59:46 PM    12/31/2018            CARDBR
# 1         11:49:42 PM    12/31/2018               UNC
# 2         11:38:46 PM    12/31/2018               UNC
# 3         11:24:58 PM    12/31/2018              SICK
# 4         11:23:35 PM    12/31/2018            SICMIN
# 5         11:12:16 PM    12/31/2018               EDP
# 6         11:11:42 PM    12/31/2018               UNC
# 7         11:10:33 PM    12/31/2018            PEDSTR
# 8         11:08:20 PM    12/31/2018               EDP
# 9         11:06:25 PM    12/31/2018            INBLED
# 10        11:04:54 PM    12/31/2018              SICK
# 11        10:52:10 PM    12/31/2018              DRUG
# 12        10:46:37 PM    12/31/2018            MVAINJ
# 13        10:30:43 PM    12/31/2018               EDP
# 14        10:09:29 PM    12/31/2018            INJMAJ
# 15        10:08:50 PM    12/31/2018             SEIZR
# ...

# %%
travel = mv_clean[['ZIPCODE',"INITIAL_SEVERITY_LEVEL_CODE", 'INCIDENT_TRAVEL_TM_SECONDS_QY']].groupby(['ZIPCODE',"INITIAL_SEVERITY_LEVEL_CODE"]).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-149-cc24705a3dcd> in <module>
# ----> 1 travel = mv_clean[['ZIPCODE',"INITIAL_SEVERITY_LEVEL_CODE", 'INCIDENT_TRAVEL_TM_SECONDS_QY']].groupby(['ZIPCODE',"INITIAL_SEVERITY_LEVEL_CODE"]).mean()
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# ...

# %%
travel
# Out:
#                                      INCIDENT_TRAVEL_TM_SECONDS_QY
# ZIPCODE INITIAL_SEVERITY_LEVEL_CODE
# 10000.0 1                                               123.000000
#         2                                               536.041667
#         3                                               528.869565
#         4                                               641.282051
#         5                                               722.900826
#         6                                               700.107143
#         7                                               887.568182
#         8                                              1232.000000
# 10001.0 1                                               249.702550
#         2                                               376.279070
#         3                                               376.389774
#         4                                               500.230435
# ...

# %%
travel.loc[11697]
# Out:
#                              INCIDENT_TRAVEL_TM_SECONDS_QY
# INITIAL_SEVERITY_LEVEL_CODE
# 1                                               706.666667
# 2                                               723.253968
# 3                                               768.438095
# 4                                               759.265896
# 5                                               866.869565
# 6                                               933.280702
# 7                                              1025.901961

# %%
travel.loc[10314]
# Out:
#                              INCIDENT_TRAVEL_TM_SECONDS_QY
# INITIAL_SEVERITY_LEVEL_CODE
# 1                                               286.112469
# 2                                               384.921527
# 3                                               369.446379
# 4                                               415.161057
# 5                                               429.857764
# 6                                               435.831751
# 7                                               610.148131
# 9                                                 7.000000

# %%
travel.loc[11201]
# Out:
#                              INCIDENT_TRAVEL_TM_SECONDS_QY
# INITIAL_SEVERITY_LEVEL_CODE
# 1                                               232.832432
# 2                                               349.858689
# 3                                               349.078326
# 4                                               451.460599
# 5                                               461.340072
# 6                                               455.003718
# 7                                               662.146272
# 8                                              4360.400000

# %%
## zipcodes with 83 are bad data

# %%
#replace all NaN 

mv_clean = mv_clean.merge(travel,on = ['ZIPCODE','INITIAL_SEVERITY_LEVEL_CODE'])

# %%
mv_clean #delete special event SPEVNT
# Out:
#         Incident_Date Incident_Time INITIAL_CALL_TYPE  \
# 0         11:59:46 PM    12/31/2018            CARDBR
# 1         11:49:42 PM    12/31/2018               UNC
# 2         08:11:30 PM    12/31/2018             ANAPH
# 3         06:59:33 PM    12/31/2018            DIFFBR
# 4         04:40:10 PM    12/31/2018            STATEP
# 5         01:34:04 PM    12/31/2018            STATEP
# 6         09:47:08 AM    12/31/2018            DIFFBR
# 7         09:06:17 AM    12/31/2018            ASTHMB
# 8         02:58:59 AM    12/31/2018            CARDBR
# 9         02:57:50 AM    12/31/2018               UNC
# 10        11:33:50 PM    12/30/2018               UNC
# 11        11:06:34 PM    12/30/2018            DIFFBR
# 12        06:12:44 PM    12/30/2018            CARDBR
# 13        04:36:01 PM    12/30/2018              CVAC
# 14        02:30:18 PM    12/30/2018            DIFFBR
# 15        12:35:47 PM    12/30/2018               UNC
# ...

# %%
travel['ZIPCODE']
# Out:
#   File "<ipython-input-112-b4fcdc04e914>", line 1
#     travel[column = 'ZIPCODE']
#                   ^
# SyntaxError: invalid syntax

# %%
travel.loc[travel['ZIPCODE'] == 11201]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ZIPCODE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-4ad9b172858a> in <module>
# ...
